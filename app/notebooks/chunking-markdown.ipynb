# %% [markdown]
# # Chunking using a markdown tree

# %%
import sys
sys.path.append("../")
from src.ingestion.markdown_tree import *

# %% [markdown]
# Tech details: Major libraries used:
# - mistletoe - for markdown parsing and rendering; this creates tokens
# - nutree - for representing and reasoning over the tree; this creates nodes that wrap around tokens

# %% [markdown]
# ## Generic Demo

# %%
markdown_text = """
This is the first paragraph with no heading.

# Heading 1

First paragraph under Heading 1. Paragraph H1.p1, sentence 2. Paragraph H1.p1, sentence 3. Paragraph H1.p1, sentence 4. Last sentence of 'H1.p1'.

Second paragraph under Heading 1. Paragraph H1.p2, sentence 2. Paragraph H1.p2, sentence 3. Paragraph H1.p2, sentence 4. Paragraph H1.p2, sentence 5. Paragraph H1.p2, sentence 6. Last sentence of 'H1.p2'.

## Heading 2

Paragraph 1 under Heading 2 with [a link](http://to.nowhere.com). Paragraph H2.p1, sentence 2. Paragraph H2.p1, sentence 3. Paragraph H2.p1, sentence 4. Last sentence of 'H2.p1'.

Paragraph 2 under Heading 2. Paragraph H2.p2, sentence 2. Paragraph H2.p2, sentence 3. Paragraph H2.p2, sentence 4. Paragraph H2.p2, sentence 5. Paragraph H2.p2, sentence 6. Last sentence of 'H2.p2'.

List intro:
* Item H2.3.L1.1
* Item H2.3.L1.2
* Item H2.3.L1.3

### Heading 3

Only paragraph under **Heading 3**. Paragraph H3.p1, sentence 2. Paragraph H3.p1, sentence 3. Paragraph H3.p1, sentence 4. Last sentence.

Table intro:
| H3.2.T1: header 1 | H3.2.T1: header 2 | H3.2.T1: header 3 | H3.2.T1: header 4 |
|---|---|---|---|
| H3.2.T1: row 1, col 1 | H3.2.T1: row 1, col 2 | H3.2.T1: row 1, col 3 | H3.2.T1: row 1, col 4 |
| H3.2.T1: row 2, col 1 | H3.2.T1: row 2, col 2 | H3.2.T1: row 2, col 3 | H3.2.T1: row 2, col 4 |
| H3.2.T1: row 3, col 1 | H3.2.T1: row 3, col 2 | H3.2.T1: row 3, col 3 | H3.2.T1: row 3, col 4 |

# Second H1 without a paragraph

### Skip to H3

A paragraph under "Second H1>Heading 3". Paragraph H1>H3.p1, sentence 2. Paragraph H1>H3.p1, sentence 3. Following list has *no* intro.

* Item H1>H3.L1.1
* Item H1>H3.L1.2
  * Item H1>H3.L1.subL.1
    * Item H1>H3.L1.subL.2
      * Item H1>H3.L1.subL.3
* Item H1>H3.L1.1
* Item H1>H3.L1.2

Paragraph before list with long list items.
* H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4.
* H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5.
* H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph L2.item3, sentence 6.
* H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4.
* H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5.
* H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph L2.item3, sentence 6.

Final paragraph.
"""
# Out:
# '\nThis is the first paragraph with no heading.\n\n# Heading 1\n\nFirst paragraph under Heading 1. Paragraph H1.p1, sentence 2. Paragraph H1.p1, sentence 3. Paragraph H1.p1, sentence 4. Last sentence of \'H1.p1\'.\n\nSecond paragraph under Heading 1. Paragraph H1.p2, sentence 2. Paragraph H1.p2, sentence 3. Paragraph H1.p2, sentence 4. Paragraph H1.p2, sentence 5. Paragraph H1.p2, sentence 6. Last sentence of \'H1.p2\'.\n\n## Heading 2\n\nParagraph 1 under Heading 2 with [a link](http://to.nowhere.com). Paragraph H2.p1, sentence 2. Paragraph H2.p1, sentence 3. Paragraph H2.p1, sentence 4. Last sentence of \'H2.p1\'.\n\nParagraph 2 under Heading 2. Paragraph H2.p2, sentence 2. Paragraph H2.p2, sentence 3. Paragraph H2.p2, sentence 4. Paragraph H2.p2, sentence 5. Paragraph H2.p2, sentence 6. Last sentence of \'H2.p2\'.\n\nList intro:\n* Item H2.3.L1.1\n* Item H2.3.L1.2\n* Item H2.3.L1.3\n\n### Heading 3\n\nOnly paragraph under **Heading 3**. Paragraph H3.p1, sentence 2. Paragraph H3.p1, sentence 3. Paragraph H3.p1, sentence 4. Last sentence.\n\nTable intro:\n| H3.2.T1: header 1 | H3.2.T1: header 2 | H3.2.T1: header 3 | H3.2.T1: header 4 |\n|---|---|---|---|\n| H3.2.T1: row 1, col 1 | H3.2.T1: row 1, col 2 | H3.2.T1: row 1, col 3 | H3.2.T1: row 1, col 4 |\n| H3.2.T1: row 2, col 1 | H3.2.T1: row 2, col 2 | H3.2.T1: row 2, col 3 | H3.2.T1: row 2, col 4 |\n| H3.2.T1: row 3, col 1 | H3.2.T1: row 3, col 2 | H3.2.T1: row 3, col 3 | H3.2.T1: row 3, col 4 |\n\n# Second H1 without a paragraph\n\n### Skip to H3\n\nA paragraph under "Second H1>Heading 3". Paragraph H1>H3.p1, sentence 2. Paragraph H1>H3.p1, sentence 3. Following list has *no* intro.\n\n* Item H1>H3.L1.1\n* Item H1>H3.L1.2\n  * Item H1>H3.L1.subL.1\n    * Item H1>H3.L1.subL.2\n      * Item H1>H3.L1.subL.3\n* Item H1>H3.L1.1\n* Item H1>H3.L1.2\n\nParagraph before list with long list items.\n* H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4.\n* H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5.\n* H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph L2.item3, sentence 6.\n* H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4.\n* H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5.\n* H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph L2.item3, sentence 6.\n\nFinal paragraph.\n'

# %%
markdown = normalize_markdown(markdown_text)
print(markdown)
# Out:
# This is the first paragraph with no heading.
#
# # Heading 1
#
# First paragraph under Heading 1. Paragraph H1.p1, sentence 2. Paragraph H1.p1, sentence 3. Paragraph H1.p1, sentence 4. Last sentence of 'H1.p1'.
#
# Second paragraph under Heading 1. Paragraph H1.p2, sentence 2. Paragraph H1.p2, sentence 3. Paragraph H1.p2, sentence 4. Paragraph H1.p2, sentence 5. Paragraph H1.p2, sentence 6. Last sentence of 'H1.p2'.
#
# ## Heading 2
#
# Paragraph 1 under Heading 2 with [a link](http://to.nowhere.com). Paragraph H2.p1, sentence 2. Paragraph H2.p1, sentence 3. Paragraph H2.p1, sentence 4. Last sentence of 'H2.p1'.
#
# Paragraph 2 under Heading 2. Paragraph H2.p2, sentence 2. Paragraph H2.p2, sentence 3. Paragraph H2.p2, sentence 4. Paragraph H2.p2, sentence 5. Paragraph H2.p2, sentence 6. Last sentence of 'H2.p2'.
#
# List intro:
# * Item H2.3.L1.1
# * Item H2.3.L1.2
# * Item H2.3.L1.3
#
# ### Heading 3
#
# Only paragraph under **Heading 3**. Paragraph H3.p1, sentence 2. Paragraph H3.p1, sentence 3. Paragraph H3.p1, sentence 4. Last sentence.
#
# Table intro:
# | H3.2.T1: header 1     | H3.2.T1: header 2     | H3.2.T1: header 3     | H3.2.T1: header 4     |
# | --------------------- | --------------------- | --------------------- | --------------------- |
# | H3.2.T1: row 1, col 1 | H3.2.T1: row 1, col 2 | H3.2.T1: row 1, col 3 | H3.2.T1: row 1, col 4 |
# | H3.2.T1: row 2, col 1 | H3.2.T1: row 2, col 2 | H3.2.T1: row 2, col 3 | H3.2.T1: row 2, col 4 |
# | H3.2.T1: row 3, col 1 | H3.2.T1: row 3, col 2 | H3.2.T1: row 3, col 3 | H3.2.T1: row 3, col 4 |
#
# # Second H1 without a paragraph
#
# ### Skip to H3
#
# A paragraph under "Second H1>Heading 3". Paragraph H1>H3.p1, sentence 2. Paragraph H1>H3.p1, sentence 3. Following list has *no* intro.
#
# * Item H1>H3.L1.1
# * Item H1>H3.L1.2
#   * Item H1>H3.L1.subL.1
#     * Item H1>H3.L1.subL.2
#       * Item H1>H3.L1.subL.3
# * Item H1>H3.L1.1
# * Item H1>H3.L1.2
#
# Paragraph before list with long list items.
# * H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4.
# * H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5.
# * H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph L2.item3, sentence 6.
# * H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4.
# * H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5.
# * H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph L2.item3, sentence 6.
#
# Final paragraph.

# %%
tree = create_markdown_tree(markdown_text)
tree.print()
# Out:
# Tree<'Markdown tree'>
# ╰── Document D_1: '<mistletoe.block_token.Document with 37 children line_number=1 at 0x106871790>'
#     ├── BlankLine BL_1
#     ├── Paragraph P_2 of length 45 across 1 children
#     │   ╰── RawText s.0: "<mistletoe.span_token.RawText content='This is the first paragraph wi'...+14 at 0x106872c00>"
#     ├── BlankLine BL_3
#     ├── Heading H1_4: '# Heading 1\n'
#     │   ╰── RawText s.1: "<mistletoe.span_token.RawText content='Heading 1' at 0x106880590>"
#     ├── BlankLine BL_5
#     ├── Paragraph P_6 of length 146 across 1 children
#     │   ╰── RawText s.2: "<mistletoe.span_token.RawText content='First paragraph under Heading '...+115 at 0x106880560>"
#     ├── BlankLine BL_7
#     ├── Paragraph P_8 of length 205 across 1 children
#     │   ╰── RawText s.3: "<mistletoe.span_token.RawText content='Second paragraph under Heading'...+174 at 0x106880740>"
#     ├── BlankLine BL_9
#     ├── Heading H2_10: '## Heading 2\n'
#     │   ╰── RawText s.4: "<mistletoe.span_token.RawText content='Heading 2' at 0x106a007d0>"
#     ├── BlankLine BL_11
#     ├── Paragraph P_12 of length 179 across 3 children
#     │   ├── RawText s.5: "<mistletoe.span_token.RawText content='Paragraph 1 under Heading 2 wi'...+3 at 0x106a009b0>"
#     │   ├── Link s.6: '[a link](http://to.nowhere.com)\n'
#     │   │   ╰── RawText s.7: "<mistletoe.span_token.RawText content='a link' at 0x106a00aa0>"
#     │   ╰── RawText s.8: "<mistletoe.span_token.RawText content='. Paragraph H2.p1, sentence 2.'...+84 at 0x106a008f0>"
#     ├── BlankLine BL_13
#     ├── Paragraph P_14 of length 200 across 1 children
#     │   ╰── RawText s.9: "<mistletoe.span_token.RawText content='Paragraph 2 under Heading 2. P'...+169 at 0x106870bc0>"
#     ├── BlankLine BL_15
#     ├── Paragraph P_16 of length 12 across 1 children
#     │   ╰── RawText s.10: "<mistletoe.span_token.RawText content='List intro:' at 0x106880cb0>"
#     ├── List L_17: '<mistletoe.block_token.List with 3 children line_number=17 loose=False start=None at 0x106a00c80>'
#     │   ├── ListItem LI_17: "'* Item H2.3.L1.1\\n'"
#     │   │   ╰── Paragraph P_17 of length 15 across 1 children
#     │   │       ╰── RawText s.11: "<mistletoe.span_token.RawText content='Item H2.3.L1.1' at 0x106880e30>"
#     │   ├── ListItem LI_18: "'* Item H2.3.L1.2\\n'"
#     │   │   ╰── Paragraph P_18 of length 15 across 1 children
#     │   │       ╰── RawText s.12: "<mistletoe.span_token.RawText content='Item H2.3.L1.2' at 0x106870ef0>"
#     │   ╰── ListItem LI_19: "'* Item H2.3.L1.3\\n'"
#     │       ╰── Paragraph P_19 of length 15 across 1 children
#     │           ╰── RawText s.13: "<mistletoe.span_token.RawText content='Item H2.3.L1.3' at 0x106870fb0>"
#     ├── BlankLine BL_20
#     ├── Heading H3_21: '### Heading 3\n'
#     │   ╰── RawText s.14: "<mistletoe.span_token.RawText content='Heading 3' at 0x106880fe0>"
#     ├── BlankLine BL_22
#     ├── Paragraph P_23 of length 138 across 3 children
#     │   ├── RawText s.15: "<mistletoe.span_token.RawText content='Only paragraph under ' at 0x106a01100>"
#     │   ├── Strong s.16: '<mistletoe.span_token.Strong with 1 child at 0x106a01190>'
#     │   │   ╰── RawText s.17: "<mistletoe.span_token.RawText content='Heading 3' at 0x106a01160>"
#     │   ╰── RawText s.18: "<mistletoe.span_token.RawText content='. Paragraph H3.p1, sentence 2.'...+73 at 0x106a010a0>"
#     ├── BlankLine BL_24
#     ├── Paragraph P_25 of length 13 across 1 children
#     │   ╰── RawText s.19: "<mistletoe.span_token.RawText content='Table intro:' at 0x1068812e0>"
#     ├── Table T_26: '| H3.2.T1: header 1     | H3.2.T1: header 2     | H3.2.T1: header 3     | H3.2.T1: header 4     |'
#     │   ├── TableRow TR_28: '| H3.2.T1: row 1, col 1 | H3.2.T1: row 1, col 2 | H3.2.T1: row 1, col 3 | H3.2.T1: row 1, col 4 |'
#     │   │   ├── TableCell tc20_28
#     │   │   │   ╰── RawText s.21: "<mistletoe.span_token.RawText content='H3.2.T1: row 1, col 1' at 0x1068817c0>"
#     │   │   ├── TableCell tc22_28
#     │   │   │   ╰── RawText s.23: "<mistletoe.span_token.RawText content='H3.2.T1: row 1, col 2' at 0x1068818b0>"
#     │   │   ├── TableCell tc24_28
#     │   │   │   ╰── RawText s.25: "<mistletoe.span_token.RawText content='H3.2.T1: row 1, col 3' at 0x106871940>"
#     │   │   ╰── TableCell tc26_28
#     │   │       ╰── RawText s.27: "<mistletoe.span_token.RawText content='H3.2.T1: row 1, col 4' at 0x1068819d0>"
#     │   ├── TableRow TR_29: '| H3.2.T1: row 2, col 1 | H3.2.T1: row 2, col 2 | H3.2.T1: row 2, col 3 | H3.2.T1: row 2, col 4 |'
#     │   │   ├── TableCell tc28_29
#     │   │   │   ╰── RawText s.29: "<mistletoe.span_token.RawText content='H3.2.T1: row 2, col 1' at 0x106871af0>"
#     │   │   ├── TableCell tc30_29
#     │   │   │   ╰── RawText s.31: "<mistletoe.span_token.RawText content='H3.2.T1: row 2, col 2' at 0x106871b80>"
#     │   │   ├── TableCell tc32_29
#     │   │   │   ╰── RawText s.33: "<mistletoe.span_token.RawText content='H3.2.T1: row 2, col 3' at 0x106881c10>"
#     │   │   ╰── TableCell tc34_29
#     │   │       ╰── RawText s.35: "<mistletoe.span_token.RawText content='H3.2.T1: row 2, col 4' at 0x106871ca0>"
#     │   ╰── TableRow TR_30: '| H3.2.T1: row 3, col 1 | H3.2.T1: row 3, col 2 | H3.2.T1: row 3, col 3 | H3.2.T1: row 3, col 4 |'
#     │       ├── TableCell tc36_30
#     │       │   ╰── RawText s.37: "<mistletoe.span_token.RawText content='H3.2.T1: row 3, col 1' at 0x106a01d30>"
#     │       ├── TableCell tc38_30
#     │       │   ╰── RawText s.39: "<mistletoe.span_token.RawText content='H3.2.T1: row 3, col 2' at 0x106a01df0>"
#     │       ├── TableCell tc40_30
#     │       │   ╰── RawText s.41: "<mistletoe.span_token.RawText content='H3.2.T1: row 3, col 3' at 0x106881f40>"
#     │       ╰── TableCell tc42_30
#     │           ╰── RawText s.43: "<mistletoe.span_token.RawText content='H3.2.T1: row 3, col 4' at 0x106881fd0>"
#     ├── BlankLine BL_31
#     ├── Heading H1_32: '# Second H1 without a paragraph\n'
#     │   ╰── RawText s.44: "<mistletoe.span_token.RawText content='Second H1 without a paragraph' at 0x106871fa0>"
#     ├── BlankLine BL_33
#     ├── Heading H3_34: '### Skip to H3\n'
#     │   ╰── RawText s.45: "<mistletoe.span_token.RawText content='Skip to H3' at 0x106872090>"
#     ├── BlankLine BL_35
#     ├── Paragraph P_36 of length 136 across 3 children
#     │   ├── RawText s.46: '<mistletoe.span_token.RawText content=\'A paragraph under "Second H1>H\'...+94 at 0x106a021b0>'
#     │   ├── Emphasis s.47: '<mistletoe.span_token.Emphasis with 1 child at 0x106a022d0>'
#     │   │   ╰── RawText s.48: "<mistletoe.span_token.RawText content='no' at 0x106a022a0>"
#     │   ╰── RawText s.49: "<mistletoe.span_token.RawText content=' intro.' at 0x106a02300>"
#     ├── BlankLine BL_37
#     ├── List L_38: '<mistletoe.block_token.List with 4 children line_number=38 loose=False start=None at 0x106a02210>'
#     │   ├── ListItem LI_38: "'* Item H1>H3.L1.1\\n'"
#     │   │   ╰── Paragraph P_38 of length 16 across 1 children
#     │   │       ╰── RawText s.50: "<mistletoe.span_token.RawText content='Item H1>H3.L1.1' at 0x106872480>"
#     │   ├── ListItem LI_39: "'* Item H1>H3.L1.2\\n  * Item H1>H3.L1.subL.1\\n    * Item H1>H3.L1.subL.2\\n      * Item H1>H3.L1.subL.3\\n'"
#     │   │   ├── Paragraph P_39 of length 16 across 1 children
#     │   │   │   ╰── RawText s.51: "<mistletoe.span_token.RawText content='Item H1>H3.L1.2' at 0x106872540>"
#     │   │   ╰── List L_40: '<mistletoe.block_token.List with 1 child line_number=40 loose=False start=None at 0x106a02510>'
#     │   │       ╰── ListItem LI_40: "'* Item H1>H3.L1.subL.1\\n  * Item H1>H3.L1.subL.2\\n    * Item H1>H3.L1.subL.3\\n'"
#     │   │           ├── Paragraph P_40 of length 21 across 1 children
#     │   │           │   ╰── RawText s.52: "<mistletoe.span_token.RawText content='Item H1>H3.L1.subL.1' at 0x106a02690>"
#     │   │           ╰── List L_41: '<mistletoe.block_token.List with 1 child line_number=41 loose=False start=None at 0x106a026f0>'
#     │   │               ╰── ListItem LI_41: "'* Item H1>H3.L1.subL.2\\n  * Item H1>H3.L1.subL.3\\n'"
#     │   │                   ├── Paragraph P_41 of length 21 across 1 children
#     │   │                   │   ╰── RawText s.53: "<mistletoe.span_token.RawText content='Item H1>H3.L1.subL.2' at 0x106872870>"
#     │   │                   ╰── List L_42: '<mistletoe.block_token.List with 1 child line_number=42 loose=False start=None at 0x106a02840>'
#     │   │                       ╰── ListItem LI_42: "'* Item H1>H3.L1.subL.3\\n'"
#     │   │                           ╰── Paragraph P_42 of length 21 across 1 children
#     │   │                               ╰── RawText s.54: "<mistletoe.span_token.RawText content='Item H1>H3.L1.subL.3' at 0x1068729f0>"
#     │   ├── ListItem LI_43: "'* Item H1>H3.L1.1\\n'"
#     │   │   ╰── Paragraph P_43 of length 16 across 1 children
#     │   │       ╰── RawText s.55: "<mistletoe.span_token.RawText content='Item H1>H3.L1.1' at 0x106882780>"
#     │   ╰── ListItem LI_44: "'* Item H1>H3.L1.2\\n'"
#     │       ╰── Paragraph P_44 of length 16 across 1 children
#     │           ╰── RawText s.56: "<mistletoe.span_token.RawText content='Item H1>H3.L1.2' at 0x106872930>"
#     ├── BlankLine BL_45
#     ├── Paragraph P_46 of length 44 across 1 children
#     │   ╰── RawText s.57: "<mistletoe.span_token.RawText content='Paragraph before list with lon'...+13 at 0x106872a20>"
#     ├── List L_47: '<mistletoe.block_token.List with 6 children line_number=47 loose=False start=None at 0x106a029c0>'
#     │   ├── ListItem LI_47: "'* H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, '"
#     │   │   ╰── Paragraph P_47 of length 110 across 1 children
#     │   │       ╰── RawText s.58: "<mistletoe.span_token.RawText content='H1>H3.L2.1 -- Paragraph L2.ite'...+79 at 0x106872ba0>"
#     │   ├── ListItem LI_48: "'* H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, '"
#     │   │   ╰── Paragraph P_48 of length 142 across 1 children
#     │   │       ╰── RawText s.59: "<mistletoe.span_token.RawText content='H1>H3.L2.2 -- Paragraph L2.ite'...+111 at 0x106a02c30>"
#     │   ├── ListItem LI_49: "'* H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, '"
#     │   │   ╰── Paragraph P_49 of length 174 across 1 children
#     │   │       ╰── RawText s.60: "<mistletoe.span_token.RawText content='H1>H3.L2.3 -- Paragraph L2.ite'...+143 at 0x106882db0>"
#     │   ├── ListItem LI_50: "'* H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, '"
#     │   │   ╰── Paragraph P_50 of length 110 across 1 children
#     │   │       ╰── RawText s.61: "<mistletoe.span_token.RawText content='H1>H3.L2.4 -- Paragraph L2.ite'...+79 at 0x106882e70>"
#     │   ├── ListItem LI_51: "'* H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, '"
#     │   │   ╰── Paragraph P_51 of length 142 across 1 children
#     │   │       ╰── RawText s.62: "<mistletoe.span_token.RawText content='H1>H3.L2.5 -- Paragraph L2.ite'...+111 at 0x106a02f00>"
#     │   ╰── ListItem LI_52: "'* H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, '"
#     │       ╰── Paragraph P_52 of length 174 across 1 children
#     │           ╰── RawText s.63: "<mistletoe.span_token.RawText content='H1>H3.L2.6 -- Paragraph L2.ite'...+143 at 0x106a03050>"
#     ├── BlankLine BL_53
#     ╰── Paragraph P_54 of length 17 across 1 children
#         ╰── RawText s.64: "<mistletoe.span_token.RawText content='Final paragraph.' at 0x1068731a0>"

# %% [markdown]
# ### Tree examination

# %%
with AstRenderer() as ast_renderer:
    doc = mistletoe.Document(markdown_text)
    ast_json = ast_renderer.render(doc)
print(ast_json)
# Out:
# {
#   "type": "Document",
#   "footnotes": {},
#   "line_number": 1,
#   "children": [
#     {
#       "type": "Paragraph",
#       "line_number": 2,
#       "children": [
#         {
#           "type": "RawText",
#           "content": "This is the first paragraph with no heading."
#         }
#       ]
#     },
#     {
#       "type": "Heading",
#       "line_number": 4,
#       "level": 1,
#       "children": [
#         {
#           "type": "RawText",
#           "content": "Heading 1"
#         }
#       ]
#     },
#     {
#       "type": "Paragraph",
#       "line_number": 6,
#       "children": [
#         {
#           "type": "RawText",
#           "content": "First paragraph under Heading 1. Paragraph H1.p1, sentence 2. Paragraph H1.p1, sentence 3. Paragraph H1.p1, sentence 4. Last sentence of 'H1.p1'."
#         }
#       ]
#     },
#     {
#       "type": "Paragraph",
#       "line_number": 8,
#       "children": [
#         {
#           "type": "RawText",
#           "content": "Second paragraph under Heading 1. Paragraph H1.p2, sentence 2. Paragraph H1.p2, sentence 3. Paragraph H1.p2, sentence 4. Paragraph H1.p2, sentence 5. Paragraph H1.p2, sentence 6. Last sentence of 'H1.p2'."
#         }
#       ]
#     },
#     {
#       "type": "Heading",
#       "line_number": 10,
#       "level": 2,
#       "children": [
#         {
#           "type": "RawText",
#           "content": "Heading 2"
#         }
#       ]
#     },
#     {
#       "type": "Paragraph",
#       "line_number": 12,
#       "children": [
#         {
#           "type": "RawText",
#           "content": "Paragraph 1 under Heading 2 with "
#         },
#         {
#           "type": "Link",
#           "target": "http://to.nowhere.com",
#           "title": "",
#           "children": [
#             {
#               "type": "RawText",
#               "content": "a link"
#             }
#           ]
#         },
#         {
#           "type": "RawText",
#           "content": ". Paragraph H2.p1, sentence 2. Paragraph H2.p1, sentence 3. Paragraph H2.p1, sentence 4. Last sentence of 'H2.p1'."
#         }
#       ]
#     },
#     {
#       "type": "Paragraph",
#       "line_number": 14,
#       "children": [
#         {
#           "type": "RawText",
#           "content": "Paragraph 2 under Heading 2. Paragraph H2.p2, sentence 2. Paragraph H2.p2, sentence 3. Paragraph H2.p2, sentence 4. Paragraph H2.p2, sentence 5. Paragraph H2.p2, sentence 6. Last sentence of 'H2.p2'."
#         }
#       ]
#     },
#     {
#       "type": "Paragraph",
#       "line_number": 16,
#       "children": [
#         {
#           "type": "RawText",
#           "content": "List intro:"
#         }
#       ]
#     },
#     {
#       "type": "List",
#       "line_number": 17,
#       "loose": false,
#       "start": null,
#       "children": [
#         {
#           "type": "ListItem",
#           "line_number": 17,
#           "leader": "*",
#           "indentation": 0,
#           "prepend": 2,
#           "loose": false,
#           "children": [
#             {
#               "type": "Paragraph",
#               "line_number": 17,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "Item H2.3.L1.1"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "type": "ListItem",
#           "line_number": 18,
#           "leader": "*",
#           "indentation": 0,
#           "prepend": 2,
#           "loose": false,
#           "children": [
#             {
#               "type": "Paragraph",
#               "line_number": 18,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "Item H2.3.L1.2"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "type": "ListItem",
#           "line_number": 19,
#           "leader": "*",
#           "indentation": 0,
#           "prepend": 2,
#           "loose": false,
#           "children": [
#             {
#               "type": "Paragraph",
#               "line_number": 19,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "Item H2.3.L1.3"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "Heading",
#       "line_number": 21,
#       "level": 3,
#       "children": [
#         {
#           "type": "RawText",
#           "content": "Heading 3"
#         }
#       ]
#     },
#     {
#       "type": "Paragraph",
#       "line_number": 23,
#       "children": [
#         {
#           "type": "RawText",
#           "content": "Only paragraph under "
#         },
#         {
#           "type": "Strong",
#           "children": [
#             {
#               "type": "RawText",
#               "content": "Heading 3"
#             }
#           ]
#         },
#         {
#           "type": "RawText",
#           "content": ". Paragraph H3.p1, sentence 2. Paragraph H3.p1, sentence 3. Paragraph H3.p1, sentence 4. Last sentence."
#         }
#       ]
#     },
#     {
#       "type": "Paragraph",
#       "line_number": 25,
#       "children": [
#         {
#           "type": "RawText",
#           "content": "Table intro:"
#         }
#       ]
#     },
#     {
#       "type": "Table",
#       "line_number": 26,
#       "column_align": [
#         null,
#         null,
#         null,
#         null
#       ],
#       "header": {
#         "type": "TableRow",
#         "line_number": 26,
#         "row_align": [
#           null,
#           null,
#           null,
#           null
#         ],
#         "children": [
#           {
#             "type": "TableCell",
#             "line_number": 26,
#             "align": null,
#             "children": [
#               {
#                 "type": "RawText",
#                 "content": "H3.2.T1: header 1"
#               }
#             ]
#           },
#           {
#             "type": "TableCell",
#             "line_number": 26,
#             "align": null,
#             "children": [
#               {
#                 "type": "RawText",
#                 "content": "H3.2.T1: header 2"
#               }
#             ]
#           },
#           {
#             "type": "TableCell",
#             "line_number": 26,
#             "align": null,
#             "children": [
#               {
#                 "type": "RawText",
#                 "content": "H3.2.T1: header 3"
#               }
#             ]
#           },
#           {
#             "type": "TableCell",
#             "line_number": 26,
#             "align": null,
#             "children": [
#               {
#                 "type": "RawText",
#                 "content": "H3.2.T1: header 4"
#               }
#             ]
#           }
#         ]
#       },
#       "children": [
#         {
#           "type": "TableRow",
#           "line_number": 28,
#           "row_align": [
#             null,
#             null,
#             null,
#             null
#           ],
#           "children": [
#             {
#               "type": "TableCell",
#               "line_number": 28,
#               "align": null,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H3.2.T1: row 1, col 1"
#                 }
#               ]
#             },
#             {
#               "type": "TableCell",
#               "line_number": 28,
#               "align": null,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H3.2.T1: row 1, col 2"
#                 }
#               ]
#             },
#             {
#               "type": "TableCell",
#               "line_number": 28,
#               "align": null,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H3.2.T1: row 1, col 3"
#                 }
#               ]
#             },
#             {
#               "type": "TableCell",
#               "line_number": 28,
#               "align": null,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H3.2.T1: row 1, col 4"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "type": "TableRow",
#           "line_number": 29,
#           "row_align": [
#             null,
#             null,
#             null,
#             null
#           ],
#           "children": [
#             {
#               "type": "TableCell",
#               "line_number": 29,
#               "align": null,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H3.2.T1: row 2, col 1"
#                 }
#               ]
#             },
#             {
#               "type": "TableCell",
#               "line_number": 29,
#               "align": null,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H3.2.T1: row 2, col 2"
#                 }
#               ]
#             },
#             {
#               "type": "TableCell",
#               "line_number": 29,
#               "align": null,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H3.2.T1: row 2, col 3"
#                 }
#               ]
#             },
#             {
#               "type": "TableCell",
#               "line_number": 29,
#               "align": null,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H3.2.T1: row 2, col 4"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "type": "TableRow",
#           "line_number": 30,
#           "row_align": [
#             null,
#             null,
#             null,
#             null
#           ],
#           "children": [
#             {
#               "type": "TableCell",
#               "line_number": 30,
#               "align": null,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H3.2.T1: row 3, col 1"
#                 }
#               ]
#             },
#             {
#               "type": "TableCell",
#               "line_number": 30,
#               "align": null,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H3.2.T1: row 3, col 2"
#                 }
#               ]
#             },
#             {
#               "type": "TableCell",
#               "line_number": 30,
#               "align": null,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H3.2.T1: row 3, col 3"
#                 }
#               ]
#             },
#             {
#               "type": "TableCell",
#               "line_number": 30,
#               "align": null,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H3.2.T1: row 3, col 4"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "Heading",
#       "line_number": 32,
#       "level": 1,
#       "children": [
#         {
#           "type": "RawText",
#           "content": "Second H1 without a paragraph"
#         }
#       ]
#     },
#     {
#       "type": "Heading",
#       "line_number": 34,
#       "level": 3,
#       "children": [
#         {
#           "type": "RawText",
#           "content": "Skip to H3"
#         }
#       ]
#     },
#     {
#       "type": "Paragraph",
#       "line_number": 36,
#       "children": [
#         {
#           "type": "RawText",
#           "content": "A paragraph under \"Second H1>Heading 3\". Paragraph H1>H3.p1, sentence 2. Paragraph H1>H3.p1, sentence 3. Following list has "
#         },
#         {
#           "type": "Emphasis",
#           "children": [
#             {
#               "type": "RawText",
#               "content": "no"
#             }
#           ]
#         },
#         {
#           "type": "RawText",
#           "content": " intro."
#         }
#       ]
#     },
#     {
#       "type": "List",
#       "line_number": 38,
#       "loose": false,
#       "start": null,
#       "children": [
#         {
#           "type": "ListItem",
#           "line_number": 38,
#           "leader": "*",
#           "indentation": 0,
#           "prepend": 2,
#           "loose": false,
#           "children": [
#             {
#               "type": "Paragraph",
#               "line_number": 38,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "Item H1>H3.L1.1"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "type": "ListItem",
#           "line_number": 39,
#           "leader": "*",
#           "indentation": 0,
#           "prepend": 2,
#           "loose": false,
#           "children": [
#             {
#               "type": "Paragraph",
#               "line_number": 39,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "Item H1>H3.L1.2"
#                 }
#               ]
#             },
#             {
#               "type": "List",
#               "line_number": 40,
#               "loose": false,
#               "start": null,
#               "children": [
#                 {
#                   "type": "ListItem",
#                   "line_number": 40,
#                   "leader": "*",
#                   "indentation": 0,
#                   "prepend": 2,
#                   "loose": false,
#                   "children": [
#                     {
#                       "type": "Paragraph",
#                       "line_number": 40,
#                       "children": [
#                         {
#                           "type": "RawText",
#                           "content": "Item H1>H3.L1.subL.1"
#                         }
#                       ]
#                     },
#                     {
#                       "type": "List",
#                       "line_number": 41,
#                       "loose": false,
#                       "start": null,
#                       "children": [
#                         {
#                           "type": "ListItem",
#                           "line_number": 41,
#                           "leader": "*",
#                           "indentation": 0,
#                           "prepend": 2,
#                           "loose": false,
#                           "children": [
#                             {
#                               "type": "Paragraph",
#                               "line_number": 41,
#                               "children": [
#                                 {
#                                   "type": "RawText",
#                                   "content": "Item H1>H3.L1.subL.2"
#                                 }
#                               ]
#                             },
#                             {
#                               "type": "List",
#                               "line_number": 42,
#                               "loose": false,
#                               "start": null,
#                               "children": [
#                                 {
#                                   "type": "ListItem",
#                                   "line_number": 42,
#                                   "leader": "*",
#                                   "indentation": 0,
#                                   "prepend": 2,
#                                   "loose": false,
#                                   "children": [
#                                     {
#                                       "type": "Paragraph",
#                                       "line_number": 42,
#                                       "children": [
#                                         {
#                                           "type": "RawText",
#                                           "content": "Item H1>H3.L1.subL.3"
#                                         }
#                                       ]
#                                     }
#                                   ]
#                                 }
#                               ]
#                             }
#                           ]
#                         }
#                       ]
#                     }
#                   ]
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "type": "ListItem",
#           "line_number": 43,
#           "leader": "*",
#           "indentation": 0,
#           "prepend": 2,
#           "loose": false,
#           "children": [
#             {
#               "type": "Paragraph",
#               "line_number": 43,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "Item H1>H3.L1.1"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "type": "ListItem",
#           "line_number": 44,
#           "leader": "*",
#           "indentation": 0,
#           "prepend": 2,
#           "loose": false,
#           "children": [
#             {
#               "type": "Paragraph",
#               "line_number": 44,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "Item H1>H3.L1.2"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "Paragraph",
#       "line_number": 46,
#       "children": [
#         {
#           "type": "RawText",
#           "content": "Paragraph before list with long list items."
#         }
#       ]
#     },
#     {
#       "type": "List",
#       "line_number": 47,
#       "loose": false,
#       "start": null,
#       "children": [
#         {
#           "type": "ListItem",
#           "line_number": 47,
#           "leader": "*",
#           "indentation": 0,
#           "prepend": 2,
#           "loose": false,
#           "children": [
#             {
#               "type": "Paragraph",
#               "line_number": 47,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4."
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "type": "ListItem",
#           "line_number": 48,
#           "leader": "*",
#           "indentation": 0,
#           "prepend": 2,
#           "loose": false,
#           "children": [
#             {
#               "type": "Paragraph",
#               "line_number": 48,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5."
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "type": "ListItem",
#           "line_number": 49,
#           "leader": "*",
#           "indentation": 0,
#           "prepend": 2,
#           "loose": false,
#           "children": [
#             {
#               "type": "Paragraph",
#               "line_number": 49,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph L2.item3, sentence 6."
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "type": "ListItem",
#           "line_number": 50,
#           "leader": "*",
#           "indentation": 0,
#           "prepend": 2,
#           "loose": false,
#           "children": [
#             {
#               "type": "Paragraph",
#               "line_number": 50,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4."
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "type": "ListItem",
#           "line_number": 51,
#           "leader": "*",
#           "indentation": 0,
#           "prepend": 2,
#           "loose": false,
#           "children": [
#             {
#               "type": "Paragraph",
#               "line_number": 51,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5."
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "type": "ListItem",
#           "line_number": 52,
#           "leader": "*",
#           "indentation": 0,
#           "prepend": 2,
#           "loose": false,
#           "children": [
#             {
#               "type": "Paragraph",
#               "line_number": 52,
#               "children": [
#                 {
#                   "type": "RawText",
#                   "content": "H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph L2.item3, sentence 6."
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "Paragraph",
#       "line_number": 54,
#       "children": [
#         {
#           "type": "RawText",
#           "content": "Final paragraph."
#         }
#       ]
#     }
#   ]
# }

# %%
from mistletoe.base_renderer import BaseRenderer
with BaseRenderer() as ast_renderer:
    doc = mistletoe.Document(markdown_text)
    text = ast_renderer.render(doc)
print(text)
# Out:
# This is the first paragraph with no heading.Heading 1First paragraph under Heading 1. Paragraph H1.p1, sentence 2. Paragraph H1.p1, sentence 3. Paragraph H1.p1, sentence 4. Last sentence of 'H1.p1'.Second paragraph under Heading 1. Paragraph H1.p2, sentence 2. Paragraph H1.p2, sentence 3. Paragraph H1.p2, sentence 4. Paragraph H1.p2, sentence 5. Paragraph H1.p2, sentence 6. Last sentence of 'H1.p2'.Heading 2Paragraph 1 under Heading 2 with a link. Paragraph H2.p1, sentence 2. Paragraph H2.p1, sentence 3. Paragraph H2.p1, sentence 4. Last sentence of 'H2.p1'.Paragraph 2 under Heading 2. Paragraph H2.p2, sentence 2. Paragraph H2.p2, sentence 3. Paragraph H2.p2, sentence 4. Paragraph H2.p2, sentence 5. Paragraph H2.p2, sentence 6. Last sentence of 'H2.p2'.List intro:Item H2.3.L1.1Item H2.3.L1.2Item H2.3.L1.3Heading 3Only paragraph under Heading 3. Paragraph H3.p1, sentence 2. Paragraph H3.p1, sentence 3. Paragraph H3.p1, sentence 4. Last sentence.Table intro:H3.2.T1: row 1, col 1H3.2.T1: row 1, col 2H3.2.T1: row 1, col 3H3.2.T1: row 1, col 4H3.2.T1: row 2, col 1H3.2.T1: row 2, col 2H3.2.T1: row 2, col 3H3.2.T1: row 2, col 4H3.2.T1: row 3, col 1H3.2.T1: row 3, col 2H3.2.T1: row 3, col 3H3.2.T1: row 3, col 4Second H1 without a paragraphSkip to H3A paragraph under "Second H1>Heading 3". Paragraph H1>H3.p1, sentence 2. Paragraph H1>H3.p1, sentence 3. Following list has no intro.Item H1>H3.L1.1Item H1>H3.L1.2Item H1>H3.L1.subL.1Item H1>H3.L1.subL.2Item H1>H3.L1.subL.3Item H1>H3.L1.1Item H1>H3.L1.2Paragraph before list with long list items.H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4.H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5.H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph L2.item3, sentence 6.H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4.H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5.H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph L2.item3, sentence 6.Final paragraph.

# %%
def normalize_markdown(markdown: str) -> str:
    with MarkdownRenderer(normalize_whitespace=True) as renderer:
        # "the parsing phase is currently tightly connected with initiation and closing of a renderer.
        # Therefore, you should never call Document(...) outside of a with ... as renderer block"
        doc = mistletoe.Document(markdown)
        return renderer.render(doc)

md = normalize_markdown(markdown_text)
print(md)
# Out:
# This is the first paragraph with no heading.
#
# # Heading 1
#
# First paragraph under Heading 1. Paragraph H1.p1, sentence 2. Paragraph H1.p1, sentence 3. Paragraph H1.p1, sentence 4. Last sentence of 'H1.p1'.
#
# Second paragraph under Heading 1. Paragraph H1.p2, sentence 2. Paragraph H1.p2, sentence 3. Paragraph H1.p2, sentence 4. Paragraph H1.p2, sentence 5. Paragraph H1.p2, sentence 6. Last sentence of 'H1.p2'.
#
# ## Heading 2
#
# Paragraph 1 under Heading 2 with [a link](http://to.nowhere.com). Paragraph H2.p1, sentence 2. Paragraph H2.p1, sentence 3. Paragraph H2.p1, sentence 4. Last sentence of 'H2.p1'.
#
# Paragraph 2 under Heading 2. Paragraph H2.p2, sentence 2. Paragraph H2.p2, sentence 3. Paragraph H2.p2, sentence 4. Paragraph H2.p2, sentence 5. Paragraph H2.p2, sentence 6. Last sentence of 'H2.p2'.
#
# List intro:
# * Item H2.3.L1.1
# * Item H2.3.L1.2
# * Item H2.3.L1.3
#
# ### Heading 3
#
# Only paragraph under **Heading 3**. Paragraph H3.p1, sentence 2. Paragraph H3.p1, sentence 3. Paragraph H3.p1, sentence 4. Last sentence.
#
# Table intro:
# | H3.2.T1: header 1     | H3.2.T1: header 2     | H3.2.T1: header 3     | H3.2.T1: header 4     |
# | --------------------- | --------------------- | --------------------- | --------------------- |
# | H3.2.T1: row 1, col 1 | H3.2.T1: row 1, col 2 | H3.2.T1: row 1, col 3 | H3.2.T1: row 1, col 4 |
# | H3.2.T1: row 2, col 1 | H3.2.T1: row 2, col 2 | H3.2.T1: row 2, col 3 | H3.2.T1: row 2, col 4 |
# | H3.2.T1: row 3, col 1 | H3.2.T1: row 3, col 2 | H3.2.T1: row 3, col 3 | H3.2.T1: row 3, col 4 |
#
# # Second H1 without a paragraph
#
# ### Skip to H3
#
# A paragraph under "Second H1>Heading 3". Paragraph H1>H3.p1, sentence 2. Paragraph H1>H3.p1, sentence 3. Following list has *no* intro.
#
# * Item H1>H3.L1.1
# * Item H1>H3.L1.2
#   * Item H1>H3.L1.subL.1
#     * Item H1>H3.L1.subL.2
#       * Item H1>H3.L1.subL.3
# * Item H1>H3.L1.1
# * Item H1>H3.L1.2
#
# Paragraph before list with long list items.
# * H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4.
# * H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5.
# * H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph L2.item3, sentence 6.
# * H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4.
# * H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5.
# * H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph L2.item3, sentence 6.
#
# Final paragraph.

# %%
print(tree['L_38'].render())
# Out:
# * Item H1>H3.L1.1
# * Item H1>H3.L1.2
#   * Item H1>H3.L1.subL.1
#     * Item H1>H3.L1.subL.2
#       * Item H1>H3.L1.subL.3
# * Item H1>H3.L1.1
# * Item H1>H3.L1.2

# %%
print(tree['LI_39'].render())
# Out:
# * Item H1>H3.L1.2
#   * Item H1>H3.L1.subL.1
#     * Item H1>H3.L1.subL.2
#       * Item H1>H3.L1.subL.3

# %%
print(tree['LI_41'].render())
# Out:
# * Item H1>H3.L1.subL.2
#   * Item H1>H3.L1.subL.3

# %%
from pprint import pprint
pprint(describe_tree(tree))
# Out:
# {'children': defaultdict(<class 'set'>,
#                          {'Document': {'BlankLine',
#                                        'Heading',
#                                        'List',
#                                        'Paragraph',
#                                        'Table'},
#                           'Emphasis': {'RawText'},
#                           'Heading': {'RawText'},
#                           'Link': {'RawText'},
#                           'List': {'ListItem'},
#                           'ListItem': {'Paragraph', 'List'},
#                           'Paragraph': {'Emphasis',
#                                         'Link',
#                                         'RawText',
#                                         'Strong'},
#                           'Strong': {'RawText'},
#                           'Table': {'TableRow'},
#                           'TableCell': {'RawText'},
#                           'TableRow': {'TableCell'}}),
#  'counts': defaultdict(<class 'int'>,
#                        {'BlankLine': 17,
#                         'Document': 1,
#                         'Emphasis': 1,
#                         'Heading': 5,
#                         'Link': 1,
#                         'List': 6,
#                         'ListItem': 16,
#                         'Paragraph': 27,
#                         'RawText': 50,
#                         'Strong': 1,
#                         'Table': 1,
#                         'TableCell': 12,
#                         'TableRow': 3}),
#  'parents': defaultdict(<class 'set'>,
#                         {'BlankLine': {'Document'},
#                          'Emphasis': {'Paragraph'},
#                          'Heading': {'Document'},
#                          'Link': {'Paragraph'},
#                          'List': {'Document', 'ListItem'},
#                          'ListItem': {'List'},
#                          'Paragraph': {'Document', 'ListItem'},
#                          'RawText': {'Emphasis',
#                                      'Heading',
#                                      'Link',
#                                      'Paragraph',
#                                      'Strong',
#                                      'TableCell'},
#                          'Strong': {'Paragraph'},
#                          'Table': {'Document'},
#                          'TableCell': {'TableRow'},
#                          'TableRow': {'Table'}}),
#  'tokens': defaultdict(<class 'set'>,
#                        {'BlankLine': {'_children',
#                                       '_parent',
#                                       'data_id',
#                                       'line_number',
#                                       'type'},
#                         'Document': {'_children',
#                                      'data_id',
#                                      'footnotes',
#                                      'line_number',
#                                      'type'},
#                         'Emphasis': {'_children',
#                                      '_parent',
#                                      'data_id',
#                                      'delimiter',
#                                      'type'},
#                         'Heading': {'_children',
#                                     '_parent',
#                                     'closing_sequence',
#                                     'data_id',
#                                     'level',
#                                     'line_number',
#                                     'type'},
#                         'Link': {'_children',
#                                  '_parent',
#                                  'data_id',
#                                  'dest_type',
#                                  'label',
#                                  'target',
#                                  'title',
#                                  'title_delimiter',
#                                  'type'},
#                         'List': {'_children',
#                                  '_parent',
#                                  'data_id',
#                                  'line_number',
#                                  'loose',
#                                  'start',
#                                  'type'},
#                         'ListItem': {'_children',
#                                      '_parent',
#                                      'data_id',
#                                      'indentation',
#                                      'leader',
#                                      'line_number',
#                                      'loose',
#                                      'prepend',
#                                      'type'},
#                         'Paragraph': {'_children',
#                                       '_parent',
#                                       'data_id',
#                                       'line_number',
#                                       'type'},
#                         'RawText': {'content', '_parent', 'data_id', 'type'},
#                         'Strong': {'_children',
#                                    '_parent',
#                                    'data_id',
#                                    'delimiter',
#                                    'type'},
#                         'Table': {'_children',
#                                   '_parent',
#                                   'column_align',
#                                   'data_id',
#                                   'header',
#                                   'line_number',
#                                   'type'},
#                         'TableCell': {'_children',
#                                       '_parent',
#                                       'align',
#                                       'data_id',
#                                       'line_number',
#                                       'type'},
#                         'TableRow': {'_children',
#                                      '_parent',
#                                      'col_widths',
#                                      'column_align',
#                                      'data_id',
#                                      'line_number',
#                                      'row_align',
#                                      'sep_line',
#                                      'type'}})}

# %%
doc_node = tree.children[0]
len(doc_node.children)
# Out:
# 37

# %%
heading_nodes = tree.find_all(match=lambda n: n.data_type == "Heading")
pprint(heading_nodes)
len(heading_nodes)
# Out:
# [Node<"Heading H1_4: '# Heading 1\\n'", data_id=H1_4>,
#  Node<"Heading H2_10: '## Heading 2\\n'", data_id=H2_10>,
#  Node<"Heading H3_21: '### Heading 3\\n'", data_id=H3_21>,
#  Node<"Heading H1_32: '# Second H1 without a paragraph\\n'", data_id=H1_32>,
#  Node<"Heading H3_34: '### Skip to H3\\n'", data_id=H3_34>]
# 5

# %%
table_nodes = tree.find_all(match=lambda n: n.data_type == "Table")
# Out:
# [Node<"Table T_26: '| H3.2.T1: header 1     | H3.2.T1: header 2     | H3.2.T1: header 3     | H3.2.T1: header 4     |'", data_id=T_26>]

# %%
table_node = table_nodes[0]
pprint(vars(table_node))
# Out:
# {'data_id': 'T_26',
#  'data_type': 'Table',
#  'token': <mistletoe.block_token.Table with 3 children line_number=26 column_align=[None, None, None, None] at 0x106a01250>,
#  'tree': Tree<'Markdown tree'>}

# %% [markdown]
# * Tokens are a result of parsing the original markdown text
#     - They have `_parent` and `_children` attributes
# * A (tree) node holds each token and places them in a tree according to the `_parent` and `_children` attributes

# %%
pprint(vars(table_node.token))
# Out:
# {'_children': [<mistletoe.block_token.TableRow with 4 children line_number=28 row_align=[None, None, None, None] at 0x106a01340>,
#                <mistletoe.block_token.TableRow with 4 children line_number=29 row_align=[None, None, None, None] at 0x106a016a0>,
#                <mistletoe.block_token.TableRow with 4 children line_number=30 row_align=[None, None, None, None] at 0x106a01700>],
#  '_parent': <mistletoe.block_token.Document with 37 children line_number=1 at 0x106871790>,
#  'column_align': [None, None, None, None],
#  'data_id': 'T_26',
#  'header': <mistletoe.block_token.TableRow with 4 children line_number=26 row_align=[None, None, None, None] at 0x106a01310>,
#  'line_number': 26,
#  'type': 'Table'}

# %% [markdown]
# A Table token has a `header` and `children` TabelRow tokens:

# %%
table_node.token.header
# Out:
# <mistletoe.block_token.TableRow with 4 children line_number=26 row_align=[None, None, None, None] at 0x106a01310>

# %%
table_node.token.children
# Out:
# [<mistletoe.block_token.TableRow with 4 children line_number=28 row_align=[None, None, None, None] at 0x106a01340>,
#  <mistletoe.block_token.TableRow with 4 children line_number=29 row_align=[None, None, None, None] at 0x106a016a0>,
#  <mistletoe.block_token.TableRow with 4 children line_number=30 row_align=[None, None, None, None] at 0x106a01700>]

# %% [markdown]
# The token's children are reflected in the node's children:

# %%
table_node.children
# Out:
# [Node<"TableRow TR_28: '| H3.2.T1: row 1, col 1 | H3.2.T1: row 1, col 2 | H3.2.T1: row 1, col 3 | H3.2.T1: row 1, col 4 |'", data_id=TR_28>,
#  Node<"TableRow TR_29: '| H3.2.T1: row 2, col 1 | H3.2.T1: row 2, col 2 | H3.2.T1: row 2, col 3 | H3.2.T1: row 2, col 4 |'", data_id=TR_29>,
#  Node<"TableRow TR_30: '| H3.2.T1: row 3, col 1 | H3.2.T1: row 3, col 2 | H3.2.T1: row 3, col 3 | H3.2.T1: row 3, col 4 |'", data_id=TR_30>]

# %% [markdown]
# Nodes make working with and rendering tokens easier:

# %%
table_node.last_child().render()
# Out:
# '| H3.2.T1: row 3, col 1 | H3.2.T1: row 3, col 2 | H3.2.T1: row 3, col 3 | H3.2.T1: row 3, col 4 |'

# %% [markdown]
# The tree makes reasoning about the markdown structure easier (i.e., during chunking):

# %%
tree.find_all(match=lambda n: n.data_type == "List")
# Out:
# [Node<"List L_17: '<mistletoe.block_token.List with 3 children line_number=17 loose=False start=None at 0x106a00c80>'", data_id=L_17>,
#  Node<"List L_38: '<mistletoe.block_token.List with 4 children line_number=38 loose=False start=None at 0x106a02210>'", data_id=L_38>,
#  Node<"List L_40: '<mistletoe.block_token.List with 1 child line_number=40 loose=False start=None at 0x106a02510>'", data_id=L_40>,
#  Node<"List L_41: '<mistletoe.block_token.List with 1 child line_number=41 loose=False start=None at 0x106a026f0>'", data_id=L_41>,
#  Node<"List L_42: '<mistletoe.block_token.List with 1 child line_number=42 loose=False start=None at 0x106a02840>'", data_id=L_42>,
#  Node<"List L_47: '<mistletoe.block_token.List with 6 children line_number=47 loose=False start=None at 0x106a029c0>'", data_id=L_47>]

# %% [markdown]
# ### Tree preparation (before chunking)

# %% [markdown]
# For now, let's talk about "nodes" and "tokens" synonymously.
# * They have a `type`
#     - These types are either a `BlockToken` or `SpanToken`

# %%
mistletoe.block_token.BlockToken.__subclasses__()
# Out:
# [mistletoe.block_token.Document,
#  mistletoe.block_token.Heading,
#  mistletoe.block_token.SetextHeading,
#  mistletoe.block_token.Quote,
#  mistletoe.block_token.Paragraph,
#  mistletoe.block_token.BlockCode,
#  mistletoe.block_token.CodeFence,
#  mistletoe.block_token.List,
#  mistletoe.block_token.ListItem,
#  mistletoe.block_token.Table,
#  mistletoe.block_token.TableRow,
#  mistletoe.block_token.TableCell,
#  mistletoe.block_token.Footnote,
#  mistletoe.block_token.ThematicBreak,
#  mistletoe.block_token.HtmlBlock,
#  mistletoe.markdown_renderer.BlankLine]

# %% [markdown]
# A `SpanToken` token *always* appears within a `BlockToken`.
# - Block tokens are separated by a blank line in markdown text.
# - Span tokens are inline (not visually separated) in markdown text.

# %%
mistletoe.span_token.SpanToken.__subclasses__()
# Out:
# [mistletoe.span_token.CoreTokens,
#  mistletoe.span_token.Strong,
#  mistletoe.span_token.Emphasis,
#  mistletoe.span_token.InlineCode,
#  mistletoe.span_token.Strikethrough,
#  mistletoe.span_token.Image,
#  mistletoe.span_token.Link,
#  mistletoe.span_token.AutoLink,
#  mistletoe.span_token.EscapeSequence,
#  mistletoe.span_token.LineBreak,
#  mistletoe.span_token.RawText,
#  mistletoe.span_token.HtmlSpan,
#  mistletoe.span_token.XWikiBlockMacroStart,
#  mistletoe.span_token.XWikiBlockMacroEnd,
#  mistletoe.markdown_renderer.LinkReferenceDefinition]

# %%
tree.print()
# Out:
# Tree<'Markdown tree'>
# ╰── Document D_1: '<mistletoe.block_token.Document with 37 children line_number=1 at 0x106871790>'
#     ├── BlankLine BL_1
#     ├── Paragraph P_2 of length 45 across 1 children
#     │   ╰── RawText s.0: "<mistletoe.span_token.RawText content='This is the first paragraph wi'...+14 at 0x106872c00>"
#     ├── BlankLine BL_3
#     ├── Heading H1_4: '# Heading 1\n'
#     │   ╰── RawText s.1: "<mistletoe.span_token.RawText content='Heading 1' at 0x106880590>"
#     ├── BlankLine BL_5
#     ├── Paragraph P_6 of length 146 across 1 children
#     │   ╰── RawText s.2: "<mistletoe.span_token.RawText content='First paragraph under Heading '...+115 at 0x106880560>"
#     ├── BlankLine BL_7
#     ├── Paragraph P_8 of length 205 across 1 children
#     │   ╰── RawText s.3: "<mistletoe.span_token.RawText content='Second paragraph under Heading'...+174 at 0x106880740>"
#     ├── BlankLine BL_9
#     ├── Heading H2_10: '## Heading 2\n'
#     │   ╰── RawText s.4: "<mistletoe.span_token.RawText content='Heading 2' at 0x106a007d0>"
#     ├── BlankLine BL_11
#     ├── Paragraph P_12 of length 179 across 3 children
#     │   ├── RawText s.5: "<mistletoe.span_token.RawText content='Paragraph 1 under Heading 2 wi'...+3 at 0x106a009b0>"
#     │   ├── Link s.6: '[a link](http://to.nowhere.com)\n'
#     │   │   ╰── RawText s.7: "<mistletoe.span_token.RawText content='a link' at 0x106a00aa0>"
#     │   ╰── RawText s.8: "<mistletoe.span_token.RawText content='. Paragraph H2.p1, sentence 2.'...+84 at 0x106a008f0>"
#     ├── BlankLine BL_13
#     ├── Paragraph P_14 of length 200 across 1 children
#     │   ╰── RawText s.9: "<mistletoe.span_token.RawText content='Paragraph 2 under Heading 2. P'...+169 at 0x106870bc0>"
#     ├── BlankLine BL_15
#     ├── Paragraph P_16 of length 12 across 1 children
#     │   ╰── RawText s.10: "<mistletoe.span_token.RawText content='List intro:' at 0x106880cb0>"
#     ├── List L_17: '<mistletoe.block_token.List with 3 children line_number=17 loose=False start=None at 0x106a00c80>'
#     │   ├── ListItem LI_17: "'* Item H2.3.L1.1\\n'"
#     │   │   ╰── Paragraph P_17 of length 15 across 1 children
#     │   │       ╰── RawText s.11: "<mistletoe.span_token.RawText content='Item H2.3.L1.1' at 0x106880e30>"
#     │   ├── ListItem LI_18: "'* Item H2.3.L1.2\\n'"
#     │   │   ╰── Paragraph P_18 of length 15 across 1 children
#     │   │       ╰── RawText s.12: "<mistletoe.span_token.RawText content='Item H2.3.L1.2' at 0x106870ef0>"
#     │   ╰── ListItem LI_19: "'* Item H2.3.L1.3\\n'"
#     │       ╰── Paragraph P_19 of length 15 across 1 children
#     │           ╰── RawText s.13: "<mistletoe.span_token.RawText content='Item H2.3.L1.3' at 0x106870fb0>"
#     ├── BlankLine BL_20
#     ├── Heading H3_21: '### Heading 3\n'
#     │   ╰── RawText s.14: "<mistletoe.span_token.RawText content='Heading 3' at 0x106880fe0>"
#     ├── BlankLine BL_22
#     ├── Paragraph P_23 of length 138 across 3 children
#     │   ├── RawText s.15: "<mistletoe.span_token.RawText content='Only paragraph under ' at 0x106a01100>"
#     │   ├── Strong s.16: '<mistletoe.span_token.Strong with 1 child at 0x106a01190>'
#     │   │   ╰── RawText s.17: "<mistletoe.span_token.RawText content='Heading 3' at 0x106a01160>"
#     │   ╰── RawText s.18: "<mistletoe.span_token.RawText content='. Paragraph H3.p1, sentence 2.'...+73 at 0x106a010a0>"
#     ├── BlankLine BL_24
#     ├── Paragraph P_25 of length 13 across 1 children
#     │   ╰── RawText s.19: "<mistletoe.span_token.RawText content='Table intro:' at 0x1068812e0>"
#     ├── Table T_26: '| H3.2.T1: header 1     | H3.2.T1: header 2     | H3.2.T1: header 3     | H3.2.T1: header 4     |'
#     │   ├── TableRow TR_28: '| H3.2.T1: row 1, col 1 | H3.2.T1: row 1, col 2 | H3.2.T1: row 1, col 3 | H3.2.T1: row 1, col 4 |'
#     │   │   ├── TableCell tc20_28
#     │   │   │   ╰── RawText s.21: "<mistletoe.span_token.RawText content='H3.2.T1: row 1, col 1' at 0x1068817c0>"
#     │   │   ├── TableCell tc22_28
#     │   │   │   ╰── RawText s.23: "<mistletoe.span_token.RawText content='H3.2.T1: row 1, col 2' at 0x1068818b0>"
#     │   │   ├── TableCell tc24_28
#     │   │   │   ╰── RawText s.25: "<mistletoe.span_token.RawText content='H3.2.T1: row 1, col 3' at 0x106871940>"
#     │   │   ╰── TableCell tc26_28
#     │   │       ╰── RawText s.27: "<mistletoe.span_token.RawText content='H3.2.T1: row 1, col 4' at 0x1068819d0>"
#     │   ├── TableRow TR_29: '| H3.2.T1: row 2, col 1 | H3.2.T1: row 2, col 2 | H3.2.T1: row 2, col 3 | H3.2.T1: row 2, col 4 |'
#     │   │   ├── TableCell tc28_29
#     │   │   │   ╰── RawText s.29: "<mistletoe.span_token.RawText content='H3.2.T1: row 2, col 1' at 0x106871af0>"
#     │   │   ├── TableCell tc30_29
#     │   │   │   ╰── RawText s.31: "<mistletoe.span_token.RawText content='H3.2.T1: row 2, col 2' at 0x106871b80>"
#     │   │   ├── TableCell tc32_29
#     │   │   │   ╰── RawText s.33: "<mistletoe.span_token.RawText content='H3.2.T1: row 2, col 3' at 0x106881c10>"
#     │   │   ╰── TableCell tc34_29
#     │   │       ╰── RawText s.35: "<mistletoe.span_token.RawText content='H3.2.T1: row 2, col 4' at 0x106871ca0>"
#     │   ╰── TableRow TR_30: '| H3.2.T1: row 3, col 1 | H3.2.T1: row 3, col 2 | H3.2.T1: row 3, col 3 | H3.2.T1: row 3, col 4 |'
#     │       ├── TableCell tc36_30
#     │       │   ╰── RawText s.37: "<mistletoe.span_token.RawText content='H3.2.T1: row 3, col 1' at 0x106a01d30>"
#     │       ├── TableCell tc38_30
#     │       │   ╰── RawText s.39: "<mistletoe.span_token.RawText content='H3.2.T1: row 3, col 2' at 0x106a01df0>"
#     │       ├── TableCell tc40_30
#     │       │   ╰── RawText s.41: "<mistletoe.span_token.RawText content='H3.2.T1: row 3, col 3' at 0x106881f40>"
#     │       ╰── TableCell tc42_30
#     │           ╰── RawText s.43: "<mistletoe.span_token.RawText content='H3.2.T1: row 3, col 4' at 0x106881fd0>"
#     ├── BlankLine BL_31
#     ├── Heading H1_32: '# Second H1 without a paragraph\n'
#     │   ╰── RawText s.44: "<mistletoe.span_token.RawText content='Second H1 without a paragraph' at 0x106871fa0>"
#     ├── BlankLine BL_33
#     ├── Heading H3_34: '### Skip to H3\n'
#     │   ╰── RawText s.45: "<mistletoe.span_token.RawText content='Skip to H3' at 0x106872090>"
#     ├── BlankLine BL_35
#     ├── Paragraph P_36 of length 136 across 3 children
#     │   ├── RawText s.46: '<mistletoe.span_token.RawText content=\'A paragraph under "Second H1>H\'...+94 at 0x106a021b0>'
#     │   ├── Emphasis s.47: '<mistletoe.span_token.Emphasis with 1 child at 0x106a022d0>'
#     │   │   ╰── RawText s.48: "<mistletoe.span_token.RawText content='no' at 0x106a022a0>"
#     │   ╰── RawText s.49: "<mistletoe.span_token.RawText content=' intro.' at 0x106a02300>"
#     ├── BlankLine BL_37
#     ├── List L_38: '<mistletoe.block_token.List with 4 children line_number=38 loose=False start=None at 0x106a02210>'
#     │   ├── ListItem LI_38: "'* Item H1>H3.L1.1\\n'"
#     │   │   ╰── Paragraph P_38 of length 16 across 1 children
#     │   │       ╰── RawText s.50: "<mistletoe.span_token.RawText content='Item H1>H3.L1.1' at 0x106872480>"
#     │   ├── ListItem LI_39: "'* Item H1>H3.L1.2\\n  * Item H1>H3.L1.subL.1\\n    * Item H1>H3.L1.subL.2\\n      * Item H1>H3.L1.subL.3\\n'"
#     │   │   ├── Paragraph P_39 of length 16 across 1 children
#     │   │   │   ╰── RawText s.51: "<mistletoe.span_token.RawText content='Item H1>H3.L1.2' at 0x106872540>"
#     │   │   ╰── List L_40: '<mistletoe.block_token.List with 1 child line_number=40 loose=False start=None at 0x106a02510>'
#     │   │       ╰── ListItem LI_40: "'* Item H1>H3.L1.subL.1\\n  * Item H1>H3.L1.subL.2\\n    * Item H1>H3.L1.subL.3\\n'"
#     │   │           ├── Paragraph P_40 of length 21 across 1 children
#     │   │           │   ╰── RawText s.52: "<mistletoe.span_token.RawText content='Item H1>H3.L1.subL.1' at 0x106a02690>"
#     │   │           ╰── List L_41: '<mistletoe.block_token.List with 1 child line_number=41 loose=False start=None at 0x106a026f0>'
#     │   │               ╰── ListItem LI_41: "'* Item H1>H3.L1.subL.2\\n  * Item H1>H3.L1.subL.3\\n'"
#     │   │                   ├── Paragraph P_41 of length 21 across 1 children
#     │   │                   │   ╰── RawText s.53: "<mistletoe.span_token.RawText content='Item H1>H3.L1.subL.2' at 0x106872870>"
#     │   │                   ╰── List L_42: '<mistletoe.block_token.List with 1 child line_number=42 loose=False start=None at 0x106a02840>'
#     │   │                       ╰── ListItem LI_42: "'* Item H1>H3.L1.subL.3\\n'"
#     │   │                           ╰── Paragraph P_42 of length 21 across 1 children
#     │   │                               ╰── RawText s.54: "<mistletoe.span_token.RawText content='Item H1>H3.L1.subL.3' at 0x1068729f0>"
#     │   ├── ListItem LI_43: "'* Item H1>H3.L1.1\\n'"
#     │   │   ╰── Paragraph P_43 of length 16 across 1 children
#     │   │       ╰── RawText s.55: "<mistletoe.span_token.RawText content='Item H1>H3.L1.1' at 0x106882780>"
#     │   ╰── ListItem LI_44: "'* Item H1>H3.L1.2\\n'"
#     │       ╰── Paragraph P_44 of length 16 across 1 children
#     │           ╰── RawText s.56: "<mistletoe.span_token.RawText content='Item H1>H3.L1.2' at 0x106872930>"
#     ├── BlankLine BL_45
#     ├── Paragraph P_46 of length 44 across 1 children
#     │   ╰── RawText s.57: "<mistletoe.span_token.RawText content='Paragraph before list with lon'...+13 at 0x106872a20>"
#     ├── List L_47: '<mistletoe.block_token.List with 6 children line_number=47 loose=False start=None at 0x106a029c0>'
#     │   ├── ListItem LI_47: "'* H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, '"
#     │   │   ╰── Paragraph P_47 of length 110 across 1 children
#     │   │       ╰── RawText s.58: "<mistletoe.span_token.RawText content='H1>H3.L2.1 -- Paragraph L2.ite'...+79 at 0x106872ba0>"
#     │   ├── ListItem LI_48: "'* H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, '"
#     │   │   ╰── Paragraph P_48 of length 142 across 1 children
#     │   │       ╰── RawText s.59: "<mistletoe.span_token.RawText content='H1>H3.L2.2 -- Paragraph L2.ite'...+111 at 0x106a02c30>"
#     │   ├── ListItem LI_49: "'* H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, '"
#     │   │   ╰── Paragraph P_49 of length 174 across 1 children
#     │   │       ╰── RawText s.60: "<mistletoe.span_token.RawText content='H1>H3.L2.3 -- Paragraph L2.ite'...+143 at 0x106882db0>"
#     │   ├── ListItem LI_50: "'* H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, '"
#     │   │   ╰── Paragraph P_50 of length 110 across 1 children
#     │   │       ╰── RawText s.61: "<mistletoe.span_token.RawText content='H1>H3.L2.4 -- Paragraph L2.ite'...+79 at 0x106882e70>"
#     │   ├── ListItem LI_51: "'* H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, '"
#     │   │   ╰── Paragraph P_51 of length 142 across 1 children
#     │   │       ╰── RawText s.62: "<mistletoe.span_token.RawText content='H1>H3.L2.5 -- Paragraph L2.ite'...+111 at 0x106a02f00>"
#     │   ╰── ListItem LI_52: "'* H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, '"
#     │       ╰── Paragraph P_52 of length 174 across 1 children
#     │           ╰── RawText s.63: "<mistletoe.span_token.RawText content='H1>H3.L2.6 -- Paragraph L2.ite'...+143 at 0x106a03050>"
#     ├── BlankLine BL_53
#     ╰── Paragraph P_54 of length 17 across 1 children
#         ╰── RawText s.64: "<mistletoe.span_token.RawText content='Final paragraph.' at 0x1068731a0>"

# %% [markdown]
# #### Hide Span Tokens

# %%
hide_span_tokens(tree)
# Out:
# 35

# %%
tree.print()
# Out:
# Tree<'Markdown tree'>
# ╰── Document D_1: '<mistletoe.block_token.Document with 37 children line_number=1 at 0x106871790>'
#     ├── BlankLine BL_1
#     ├── Paragraph P_2 of length 45 across 1 children: 'This is the first paragraph with no heading.'
#     ├── BlankLine BL_3
#     ├── Heading H1_4: '# Heading 1'
#     ├── BlankLine BL_5
#     ├── Paragraph P_6 of length 146 across 1 children: 'First paragraph under Heading 1....(hidden)'
#     ├── BlankLine BL_7
#     ├── Paragraph P_8 of length 205 across 1 children: 'Second paragraph under Heading 1....(hidden)'
#     ├── BlankLine BL_9
#     ├── Heading H2_10: '## Heading 2'
#     ├── BlankLine BL_11
#     ├── Paragraph P_12 of length 179 across 3 children: 'Paragraph 1 under Heading 2 with [a...(hidden)'
#     ├── BlankLine BL_13
#     ├── Paragraph P_14 of length 200 across 1 children: 'Paragraph 2 under Heading 2. Paragraph...(hidden)'
#     ├── BlankLine BL_15
#     ├── Paragraph P_16 of length 12 across 1 children: 'List intro:'
#     ├── List L_17: '<mistletoe.block_token.List with 3 children line_number=17 loose=False start=None at 0x106a00c80>'
#     │   ├── ListItem LI_17: "'* Item H2.3.L1.1\\n'"
#     │   │   ╰── Paragraph P_17 of length 15 across 1 children: 'Item H2.3.L1.1'
#     │   ├── ListItem LI_18: "'* Item H2.3.L1.2\\n'"
#     │   │   ╰── Paragraph P_18 of length 15 across 1 children: 'Item H2.3.L1.2'
#     │   ╰── ListItem LI_19: "'* Item H2.3.L1.3\\n'"
#     │       ╰── Paragraph P_19 of length 15 across 1 children: 'Item H2.3.L1.3'
#     ├── BlankLine BL_20
#     ├── Heading H3_21: '### Heading 3'
#     ├── BlankLine BL_22
#     ├── Paragraph P_23 of length 138 across 3 children: 'Only paragraph under **Heading 3**....(hidden)'
#     ├── BlankLine BL_24
#     ├── Paragraph P_25 of length 13 across 1 children: 'Table intro:'
#     ├── Table T_26: '| H3.2.T1: header 1     | H3.2.T1: header 2     | H3.2.T1: header 3     | H3.2.T1: header 4     |'
#     │   ├── TableRow TR_28: '| H3.2.T1: row 1, col 1 | H3.2.T1: row...(hidden)'
#     │   ├── TableRow TR_29: '| H3.2.T1: row 2, col 1 | H3.2.T1: row...(hidden)'
#     │   ╰── TableRow TR_30: '| H3.2.T1: row 3, col 1 | H3.2.T1: row...(hidden)'
#     ├── BlankLine BL_31
#     ├── Heading H1_32: '# Second H1 without a paragraph'
#     ├── BlankLine BL_33
#     ├── Heading H3_34: '### Skip to H3'
#     ├── BlankLine BL_35
#     ├── Paragraph P_36 of length 136 across 3 children: 'A paragraph under "Second H1>Heading...(hidden)'
#     ├── BlankLine BL_37
#     ├── List L_38: '<mistletoe.block_token.List with 4 children line_number=38 loose=False start=None at 0x106a02210>'
#     │   ├── ListItem LI_38: "'* Item H1>H3.L1.1\\n'"
#     │   │   ╰── Paragraph P_38 of length 16 across 1 children: 'Item H1>H3.L1.1'
#     │   ├── ListItem LI_39: "'* Item H1>H3.L1.2\\n  * Item H1>H3.L1.subL.1\\n    * Item H1>H3.L1.subL.2\\n      * Item H1>H3.L1.subL.3\\n'"
#     │   │   ├── Paragraph P_39 of length 16 across 1 children: 'Item H1>H3.L1.2'
#     │   │   ╰── List L_40: '<mistletoe.block_token.List with 1 child line_number=40 loose=False start=None at 0x106a02510>'
#     │   │       ╰── ListItem LI_40: "'* Item H1>H3.L1.subL.1\\n  * Item H1>H3.L1.subL.2\\n    * Item H1>H3.L1.subL.3\\n'"
#     │   │           ├── Paragraph P_40 of length 21 across 1 children: 'Item H1>H3.L1.subL.1'
#     │   │           ╰── List L_41: '<mistletoe.block_token.List with 1 child line_number=41 loose=False start=None at 0x106a026f0>'
#     │   │               ╰── ListItem LI_41: "'* Item H1>H3.L1.subL.2\\n  * Item H1>H3.L1.subL.3\\n'"
#     │   │                   ├── Paragraph P_41 of length 21 across 1 children: 'Item H1>H3.L1.subL.2'
#     │   │                   ╰── List L_42: '<mistletoe.block_token.List with 1 child line_number=42 loose=False start=None at 0x106a02840>'
#     │   │                       ╰── ListItem LI_42: "'* Item H1>H3.L1.subL.3\\n'"
#     │   │                           ╰── Paragraph P_42 of length 21 across 1 children: 'Item H1>H3.L1.subL.3'
#     │   ├── ListItem LI_43: "'* Item H1>H3.L1.1\\n'"
#     │   │   ╰── Paragraph P_43 of length 16 across 1 children: 'Item H1>H3.L1.1'
#     │   ╰── ListItem LI_44: "'* Item H1>H3.L1.2\\n'"
#     │       ╰── Paragraph P_44 of length 16 across 1 children: 'Item H1>H3.L1.2'
#     ├── BlankLine BL_45
#     ├── Paragraph P_46 of length 44 across 1 children: 'Paragraph before list with long list items.'
#     ├── List L_47: '<mistletoe.block_token.List with 6 children line_number=47 loose=False start=None at 0x106a029c0>'
#     │   ├── ListItem LI_47: "'* H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, '"
#     │   │   ╰── Paragraph P_47 of length 110 across 1 children: 'H1>H3.L2.1 -- Paragraph L2.item1,...(hidden)'
#     │   ├── ListItem LI_48: "'* H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, '"
#     │   │   ╰── Paragraph P_48 of length 142 across 1 children: 'H1>H3.L2.2 -- Paragraph L2.item2,...(hidden)'
#     │   ├── ListItem LI_49: "'* H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, '"
#     │   │   ╰── Paragraph P_49 of length 174 across 1 children: 'H1>H3.L2.3 -- Paragraph L2.item3,...(hidden)'
#     │   ├── ListItem LI_50: "'* H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, '"
#     │   │   ╰── Paragraph P_50 of length 110 across 1 children: 'H1>H3.L2.4 -- Paragraph L2.item1,...(hidden)'
#     │   ├── ListItem LI_51: "'* H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, '"
#     │   │   ╰── Paragraph P_51 of length 142 across 1 children: 'H1>H3.L2.5 -- Paragraph L2.item2,...(hidden)'
#     │   ╰── ListItem LI_52: "'* H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, '"
#     │       ╰── Paragraph P_52 of length 174 across 1 children: 'H1>H3.L2.6 -- Paragraph L2.item3,...(hidden)'
#     ├── BlankLine BL_53
#     ╰── Paragraph P_54 of length 17 across 1 children: 'Final paragraph.'

# %% [markdown]
# Tech detail: The parent of hidden nodes have `"freeze_token_children"` set to True. This has later implications when copying subtrees.
#
# Flexible/Extensibility feature: Custom attributes can be added to `node.data`, useful for tree traversals and manipulations.

# %%
tree['P_47'].data["freeze_token_children"]
# Out:
# True

# %% [markdown]
# This results in fewer nodes to deal with.

# %%
tree_descr = describe_tree(tree)
# Out:
# {'counts': defaultdict(int,
#              {'Document': 1,
#               'BlankLine': 17,
#               'Paragraph': 27,
#               'Heading': 5,
#               'List': 6,
#               'ListItem': 16,
#               'Table': 1,
#               'TableRow': 3}),
#  'children': defaultdict(set,
#              {'Document': {'BlankLine',
#                'Heading',
#                'List',
#                'Paragraph',
#                'Table'},
#               'List': {'ListItem'},
#               'ListItem': {'List', 'Paragraph'},
#               'Table': {'TableRow'}}),
#  'parents': defaultdict(set,
#              {'BlankLine': {'Document'},
#               'Paragraph': {'Document', 'ListItem'},
#               'Heading': {'Document'},
#               'List': {'Document', 'ListItem'},
#               'ListItem': {'List'},
#               'Table': {'Document'},
#               'TableRow': {'Table'}}),
#  'tokens': defaultdict(set,
#              {'Document': {'_children',
#                'data_id',
#                'footnotes',
#                'line_number',
#                'type'},
#               'BlankLine': {'_children',
#                '_parent',
#                'data_id',
#                'line_number',
#                'type'},
#               'Paragraph': {'_children',
#                '_parent',
#                'data_id',
#                'line_number',
#                'type'},
#               'Heading': {'_children',
#                '_parent',
#                'closing_sequence',
#                'data_id',
#                'level',
#                'line_number',
#                'type'},
#               'List': {'_children',
#                '_parent',
#                'data_id',
#                'line_number',
#                'loose',
#                'start',
#                'type'},
#               'ListItem': {'_children',
#                '_parent',
#                'data_id',
#                'indentation',
#                'leader',
#                'line_number',
#                'loose',
#                'prepend',
#                'type'},
#               'Table': {'_children',
#                '_parent',
#                'column_align',
#                'data_id',
#                'header',
#                'line_number',
#                'type'},
#               'TableRow': {'_children',
#                '_parent',
#                'col_widths',
#                'column_align',
#                'data_id',
#                'line_number',
#                'row_align',
#                'sep_line',
#                'type'}})}

# %% [markdown]
# #### Create HeadingSection nodes (a custom "block node")
#
# Why? HeadingSections allow us to work with a Heading and its body together.
# - The out-of-the-box tree structure (which reflects the token structure) have Heading nodes as siblings of body-text nodes.
# - We want to reason about them as a single unit, i.e., a `HeadingSection`.
#
# A HeadingSection node has children:
# - Heading
# - Paragraph, List, Table
# - (sub)HeadingSection
#     - (sub)Heading
#     - Paragraph, List, Table
#     - (sub-sub)HeadingSection
#         - ...

# %%
create_heading_sections(tree)
# Out:
# 5

# %%
tree.print()
# Out:
# Tree<'Markdown tree'>
# ╰── Document D_1: '<mistletoe.block_token.Document with 37 children line_number=1 at 0x106871790>'
#     ├── BlankLine BL_1
#     ├── Paragraph P_2 of length 45 across 1 children: 'This is the first paragraph with no heading.'
#     ├── BlankLine BL_3
#     ├── HeadingSection _S1_4 with 6 children
#     │   ├── Heading H1_4: '# Heading 1'
#     │   ├── BlankLine BL_5
#     │   ├── Paragraph P_6 of length 146 across 1 children: 'First paragraph under Heading 1....(hidden)'
#     │   ├── BlankLine BL_7
#     │   ├── Paragraph P_8 of length 205 across 1 children: 'Second paragraph under Heading 1....(hidden)'
#     │   ╰── BlankLine BL_9
#     ├── HeadingSection _S2_10 with 9 children
#     │   ├── Heading H2_10: '## Heading 2'
#     │   ├── BlankLine BL_11
#     │   ├── Paragraph P_12 of length 179 across 3 children: 'Paragraph 1 under Heading 2 with [a...(hidden)'
#     │   ├── BlankLine BL_13
#     │   ├── Paragraph P_14 of length 200 across 1 children: 'Paragraph 2 under Heading 2. Paragraph...(hidden)'
#     │   ├── BlankLine BL_15
#     │   ├── Paragraph P_16 of length 12 across 1 children: 'List intro:'
#     │   ├── List L_17: '<mistletoe.block_token.List with 3 children line_number=17 loose=False start=None at 0x106a00c80>'
#     │   │   ├── ListItem LI_17: "'* Item H2.3.L1.1\\n'"
#     │   │   │   ╰── Paragraph P_17 of length 15 across 1 children: 'Item H2.3.L1.1'
#     │   │   ├── ListItem LI_18: "'* Item H2.3.L1.2\\n'"
#     │   │   │   ╰── Paragraph P_18 of length 15 across 1 children: 'Item H2.3.L1.2'
#     │   │   ╰── ListItem LI_19: "'* Item H2.3.L1.3\\n'"
#     │   │       ╰── Paragraph P_19 of length 15 across 1 children: 'Item H2.3.L1.3'
#     │   ╰── BlankLine BL_20
#     ├── HeadingSection _S3_21 with 7 children
#     │   ├── Heading H3_21: '### Heading 3'
#     │   ├── BlankLine BL_22
#     │   ├── Paragraph P_23 of length 138 across 3 children: 'Only paragraph under **Heading 3**....(hidden)'
#     │   ├── BlankLine BL_24
#     │   ├── Paragraph P_25 of length 13 across 1 children: 'Table intro:'
#     │   ├── Table T_26: '| H3.2.T1: header 1     | H3.2.T1: header 2     | H3.2.T1: header 3     | H3.2.T1: header 4     |'
#     │   │   ├── TableRow TR_28: '| H3.2.T1: row 1, col 1 | H3.2.T1: row...(hidden)'
#     │   │   ├── TableRow TR_29: '| H3.2.T1: row 2, col 1 | H3.2.T1: row...(hidden)'
#     │   │   ╰── TableRow TR_30: '| H3.2.T1: row 3, col 1 | H3.2.T1: row...(hidden)'
#     │   ╰── BlankLine BL_31
#     ├── HeadingSection _S1_32 with 2 children
#     │   ├── Heading H1_32: '# Second H1 without a paragraph'
#     │   ╰── BlankLine BL_33
#     ╰── HeadingSection _S3_34 with 10 children
#         ├── Heading H3_34: '### Skip to H3'
#         ├── BlankLine BL_35
#         ├── Paragraph P_36 of length 136 across 3 children: 'A paragraph under "Second H1>Heading...(hidden)'
#         ├── BlankLine BL_37
#         ├── List L_38: '<mistletoe.block_token.List with 4 children line_number=38 loose=False start=None at 0x106a02210>'
#         │   ├── ListItem LI_38: "'* Item H1>H3.L1.1\\n'"
#         │   │   ╰── Paragraph P_38 of length 16 across 1 children: 'Item H1>H3.L1.1'
#         │   ├── ListItem LI_39: "'* Item H1>H3.L1.2\\n  * Item H1>H3.L1.subL.1\\n    * Item H1>H3.L1.subL.2\\n      * Item H1>H3.L1.subL.3\\n'"
#         │   │   ├── Paragraph P_39 of length 16 across 1 children: 'Item H1>H3.L1.2'
#         │   │   ╰── List L_40: '<mistletoe.block_token.List with 1 child line_number=40 loose=False start=None at 0x106a02510>'
#         │   │       ╰── ListItem LI_40: "'* Item H1>H3.L1.subL.1\\n  * Item H1>H3.L1.subL.2\\n    * Item H1>H3.L1.subL.3\\n'"
#         │   │           ├── Paragraph P_40 of length 21 across 1 children: 'Item H1>H3.L1.subL.1'
#         │   │           ╰── List L_41: '<mistletoe.block_token.List with 1 child line_number=41 loose=False start=None at 0x106a026f0>'
#         │   │               ╰── ListItem LI_41: "'* Item H1>H3.L1.subL.2\\n  * Item H1>H3.L1.subL.3\\n'"
#         │   │                   ├── Paragraph P_41 of length 21 across 1 children: 'Item H1>H3.L1.subL.2'
#         │   │                   ╰── List L_42: '<mistletoe.block_token.List with 1 child line_number=42 loose=False start=None at 0x106a02840>'
#         │   │                       ╰── ListItem LI_42: "'* Item H1>H3.L1.subL.3\\n'"
#         │   │                           ╰── Paragraph P_42 of length 21 across 1 children: 'Item H1>H3.L1.subL.3'
#         │   ├── ListItem LI_43: "'* Item H1>H3.L1.1\\n'"
#         │   │   ╰── Paragraph P_43 of length 16 across 1 children: 'Item H1>H3.L1.1'
#         │   ╰── ListItem LI_44: "'* Item H1>H3.L1.2\\n'"
#         │       ╰── Paragraph P_44 of length 16 across 1 children: 'Item H1>H3.L1.2'
#         ├── BlankLine BL_45
#         ├── Paragraph P_46 of length 44 across 1 children: 'Paragraph before list with long list items.'
#         ├── List L_47: '<mistletoe.block_token.List with 6 children line_number=47 loose=False start=None at 0x106a029c0>'
#         │   ├── ListItem LI_47: "'* H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, '"
#         │   │   ╰── Paragraph P_47 of length 110 across 1 children: 'H1>H3.L2.1 -- Paragraph L2.item1,...(hidden)'
#         │   ├── ListItem LI_48: "'* H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, '"
#         │   │   ╰── Paragraph P_48 of length 142 across 1 children: 'H1>H3.L2.2 -- Paragraph L2.item2,...(hidden)'
#         │   ├── ListItem LI_49: "'* H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, '"
#         │   │   ╰── Paragraph P_49 of length 174 across 1 children: 'H1>H3.L2.3 -- Paragraph L2.item3,...(hidden)'
#         │   ├── ListItem LI_50: "'* H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, '"
#         │   │   ╰── Paragraph P_50 of length 110 across 1 children: 'H1>H3.L2.4 -- Paragraph L2.item1,...(hidden)'
#         │   ├── ListItem LI_51: "'* H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, '"
#         │   │   ╰── Paragraph P_51 of length 142 across 1 children: 'H1>H3.L2.5 -- Paragraph L2.item2,...(hidden)'
#         │   ╰── ListItem LI_52: "'* H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, '"
#         │       ╰── Paragraph P_52 of length 174 across 1 children: 'H1>H3.L2.6 -- Paragraph L2.item3,...(hidden)'
#         ├── BlankLine BL_53
#         ╰── Paragraph P_54 of length 17 across 1 children: 'Final paragraph.'

# %% [markdown]
# #### Nest HeadingSections
#
# Makes the tree look more hierarchical so we can work with a HeadingSection and all its descendant HeadingSections as a single unit (i.e., a subtree).

# %%
nest_heading_sections(tree)
# Out:
# 3

# %%
tree.print()
# Out:
# Tree<'Markdown tree'>
# ╰── Document D_1: '<mistletoe.block_token.Document with 37 children line_number=1 at 0x106871790>'
#     ├── BlankLine BL_1
#     ├── Paragraph P_2 of length 45 across 1 children: 'This is the first paragraph with no heading.'
#     ├── BlankLine BL_3
#     ├── HeadingSection _S1_4 with 7 children
#     │   ├── Heading H1_4: '# Heading 1'
#     │   ├── BlankLine BL_5
#     │   ├── Paragraph P_6 of length 146 across 1 children: 'First paragraph under Heading 1....(hidden)'
#     │   ├── BlankLine BL_7
#     │   ├── Paragraph P_8 of length 205 across 1 children: 'Second paragraph under Heading 1....(hidden)'
#     │   ├── BlankLine BL_9
#     │   ╰── HeadingSection _S2_10 with 10 children
#     │       ├── Heading H2_10: '## Heading 2'
#     │       ├── BlankLine BL_11
#     │       ├── Paragraph P_12 of length 179 across 3 children: 'Paragraph 1 under Heading 2 with [a...(hidden)'
#     │       ├── BlankLine BL_13
#     │       ├── Paragraph P_14 of length 200 across 1 children: 'Paragraph 2 under Heading 2. Paragraph...(hidden)'
#     │       ├── BlankLine BL_15
#     │       ├── Paragraph P_16 of length 12 across 1 children: 'List intro:'
#     │       ├── List L_17: '<mistletoe.block_token.List with 3 children line_number=17 loose=False start=None at 0x106a00c80>'
#     │       │   ├── ListItem LI_17: "'* Item H2.3.L1.1\\n'"
#     │       │   │   ╰── Paragraph P_17 of length 15 across 1 children: 'Item H2.3.L1.1'
#     │       │   ├── ListItem LI_18: "'* Item H2.3.L1.2\\n'"
#     │       │   │   ╰── Paragraph P_18 of length 15 across 1 children: 'Item H2.3.L1.2'
#     │       │   ╰── ListItem LI_19: "'* Item H2.3.L1.3\\n'"
#     │       │       ╰── Paragraph P_19 of length 15 across 1 children: 'Item H2.3.L1.3'
#     │       ├── BlankLine BL_20
#     │       ╰── HeadingSection _S3_21 with 7 children
#     │           ├── Heading H3_21: '### Heading 3'
#     │           ├── BlankLine BL_22
#     │           ├── Paragraph P_23 of length 138 across 3 children: 'Only paragraph under **Heading 3**....(hidden)'
#     │           ├── BlankLine BL_24
#     │           ├── Paragraph P_25 of length 13 across 1 children: 'Table intro:'
#     │           ├── Table T_26: '| H3.2.T1: header 1     | H3.2.T1: header 2     | H3.2.T1: header 3     | H3.2.T1: header 4     |'
#     │           │   ├── TableRow TR_28: '| H3.2.T1: row 1, col 1 | H3.2.T1: row...(hidden)'
#     │           │   ├── TableRow TR_29: '| H3.2.T1: row 2, col 1 | H3.2.T1: row...(hidden)'
#     │           │   ╰── TableRow TR_30: '| H3.2.T1: row 3, col 1 | H3.2.T1: row...(hidden)'
#     │           ╰── BlankLine BL_31
#     ╰── HeadingSection _S1_32 with 3 children
#         ├── Heading H1_32: '# Second H1 without a paragraph'
#         ├── BlankLine BL_33
#         ╰── HeadingSection _S3_34 with 10 children
#             ├── Heading H3_34: '### Skip to H3'
#             ├── BlankLine BL_35
#             ├── Paragraph P_36 of length 136 across 3 children: 'A paragraph under "Second H1>Heading...(hidden)'
#             ├── BlankLine BL_37
#             ├── List L_38: '<mistletoe.block_token.List with 4 children line_number=38 loose=False start=None at 0x106a02210>'
#             │   ├── ListItem LI_38: "'* Item H1>H3.L1.1\\n'"
#             │   │   ╰── Paragraph P_38 of length 16 across 1 children: 'Item H1>H3.L1.1'
#             │   ├── ListItem LI_39: "'* Item H1>H3.L1.2\\n  * Item H1>H3.L1.subL.1\\n    * Item H1>H3.L1.subL.2\\n      * Item H1>H3.L1.subL.3\\n'"
#             │   │   ├── Paragraph P_39 of length 16 across 1 children: 'Item H1>H3.L1.2'
#             │   │   ╰── List L_40: '<mistletoe.block_token.List with 1 child line_number=40 loose=False start=None at 0x106a02510>'
#             │   │       ╰── ListItem LI_40: "'* Item H1>H3.L1.subL.1\\n  * Item H1>H3.L1.subL.2\\n    * Item H1>H3.L1.subL.3\\n'"
#             │   │           ├── Paragraph P_40 of length 21 across 1 children: 'Item H1>H3.L1.subL.1'
#             │   │           ╰── List L_41: '<mistletoe.block_token.List with 1 child line_number=41 loose=False start=None at 0x106a026f0>'
#             │   │               ╰── ListItem LI_41: "'* Item H1>H3.L1.subL.2\\n  * Item H1>H3.L1.subL.3\\n'"
#             │   │                   ├── Paragraph P_41 of length 21 across 1 children: 'Item H1>H3.L1.subL.2'
#             │   │                   ╰── List L_42: '<mistletoe.block_token.List with 1 child line_number=42 loose=False start=None at 0x106a02840>'
#             │   │                       ╰── ListItem LI_42: "'* Item H1>H3.L1.subL.3\\n'"
#             │   │                           ╰── Paragraph P_42 of length 21 across 1 children: 'Item H1>H3.L1.subL.3'
#             │   ├── ListItem LI_43: "'* Item H1>H3.L1.1\\n'"
#             │   │   ╰── Paragraph P_43 of length 16 across 1 children: 'Item H1>H3.L1.1'
#             │   ╰── ListItem LI_44: "'* Item H1>H3.L1.2\\n'"
#             │       ╰── Paragraph P_44 of length 16 across 1 children: 'Item H1>H3.L1.2'
#             ├── BlankLine BL_45
#             ├── Paragraph P_46 of length 44 across 1 children: 'Paragraph before list with long list items.'
#             ├── List L_47: '<mistletoe.block_token.List with 6 children line_number=47 loose=False start=None at 0x106a029c0>'
#             │   ├── ListItem LI_47: "'* H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, '"
#             │   │   ╰── Paragraph P_47 of length 110 across 1 children: 'H1>H3.L2.1 -- Paragraph L2.item1,...(hidden)'
#             │   ├── ListItem LI_48: "'* H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, '"
#             │   │   ╰── Paragraph P_48 of length 142 across 1 children: 'H1>H3.L2.2 -- Paragraph L2.item2,...(hidden)'
#             │   ├── ListItem LI_49: "'* H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, '"
#             │   │   ╰── Paragraph P_49 of length 174 across 1 children: 'H1>H3.L2.3 -- Paragraph L2.item3,...(hidden)'
#             │   ├── ListItem LI_50: "'* H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, '"
#             │   │   ╰── Paragraph P_50 of length 110 across 1 children: 'H1>H3.L2.4 -- Paragraph L2.item1,...(hidden)'
#             │   ├── ListItem LI_51: "'* H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, '"
#             │   │   ╰── Paragraph P_51 of length 142 across 1 children: 'H1>H3.L2.5 -- Paragraph L2.item2,...(hidden)'
#             │   ╰── ListItem LI_52: "'* H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, '"
#             │       ╰── Paragraph P_52 of length 174 across 1 children: 'H1>H3.L2.6 -- Paragraph L2.item3,...(hidden)'
#             ├── BlankLine BL_53
#             ╰── Paragraph P_54 of length 17 across 1 children: 'Final paragraph.'

# %% [markdown]
# #### Add intro sentences to List and Tables
#
# We want introductory/preceding sentences for List and Tables. Those sentences are in previous siblings of the List/Table. Let's save the intro sentence to the List/Table node now before splitting and chunking.

# %%
tree.print()
# Out:
# Tree<'Markdown tree'>
# ╰── Document D_1: '<mistletoe.block_token.Document with 37 children line_number=1 at 0x106871790>'
#     ├── BlankLine BL_1
#     ├── Paragraph P_2 of length 45 across 1 children: 'This is the first paragraph with no heading.'
#     ├── BlankLine BL_3
#     ├── HeadingSection _S1_4 with 7 children
#     │   ├── Heading H1_4: '# Heading 1'
#     │   ├── BlankLine BL_5
#     │   ├── Paragraph P_6 of length 146 across 1 children: 'First paragraph under Heading 1....(hidden)'
#     │   ├── BlankLine BL_7
#     │   ├── Paragraph P_8 of length 205 across 1 children: 'Second paragraph under Heading 1....(hidden)'
#     │   ├── BlankLine BL_9
#     │   ╰── HeadingSection _S2_10 with 10 children
#     │       ├── Heading H2_10: '## Heading 2'
#     │       ├── BlankLine BL_11
#     │       ├── Paragraph P_12 of length 179 across 3 children: 'Paragraph 1 under Heading 2 with [a...(hidden)'
#     │       ├── BlankLine BL_13
#     │       ├── Paragraph P_14 of length 200 across 1 children: 'Paragraph 2 under Heading 2. Paragraph...(hidden)'
#     │       ├── BlankLine BL_15
#     │       ├── Paragraph P_16 of length 12 across 1 children: 'List intro:'
#     │       ├── List L_17: '<mistletoe.block_token.List with 3 children line_number=17 loose=False start=None at 0x106a00c80>'
#     │       │   ├── ListItem LI_17: "'* Item H2.3.L1.1\\n'"
#     │       │   │   ╰── Paragraph P_17 of length 15 across 1 children: 'Item H2.3.L1.1'
#     │       │   ├── ListItem LI_18: "'* Item H2.3.L1.2\\n'"
#     │       │   │   ╰── Paragraph P_18 of length 15 across 1 children: 'Item H2.3.L1.2'
#     │       │   ╰── ListItem LI_19: "'* Item H2.3.L1.3\\n'"
#     │       │       ╰── Paragraph P_19 of length 15 across 1 children: 'Item H2.3.L1.3'
#     │       ├── BlankLine BL_20
#     │       ╰── HeadingSection _S3_21 with 7 children
#     │           ├── Heading H3_21: '### Heading 3'
#     │           ├── BlankLine BL_22
#     │           ├── Paragraph P_23 of length 138 across 3 children: 'Only paragraph under **Heading 3**....(hidden)'
#     │           ├── BlankLine BL_24
#     │           ├── Paragraph P_25 of length 13 across 1 children: 'Table intro:'
#     │           ├── Table T_26: '| H3.2.T1: header 1     | H3.2.T1: header 2     | H3.2.T1: header 3     | H3.2.T1: header 4     |'
#     │           │   ├── TableRow TR_28: '| H3.2.T1: row 1, col 1 | H3.2.T1: row...(hidden)'
#     │           │   ├── TableRow TR_29: '| H3.2.T1: row 2, col 1 | H3.2.T1: row...(hidden)'
#     │           │   ╰── TableRow TR_30: '| H3.2.T1: row 3, col 1 | H3.2.T1: row...(hidden)'
#     │           ╰── BlankLine BL_31
#     ╰── HeadingSection _S1_32 with 3 children
#         ├── Heading H1_32: '# Second H1 without a paragraph'
#         ├── BlankLine BL_33
#         ╰── HeadingSection _S3_34 with 10 children
#             ├── Heading H3_34: '### Skip to H3'
#             ├── BlankLine BL_35
#             ├── Paragraph P_36 of length 136 across 3 children: 'A paragraph under "Second H1>Heading...(hidden)'
#             ├── BlankLine BL_37
#             ├── List L_38: '<mistletoe.block_token.List with 4 children line_number=38 loose=False start=None at 0x106a02210>'
#             │   ├── ListItem LI_38: "'* Item H1>H3.L1.1\\n'"
#             │   │   ╰── Paragraph P_38 of length 16 across 1 children: 'Item H1>H3.L1.1'
#             │   ├── ListItem LI_39: "'* Item H1>H3.L1.2\\n  * Item H1>H3.L1.subL.1\\n    * Item H1>H3.L1.subL.2\\n      * Item H1>H3.L1.subL.3\\n'"
#             │   │   ├── Paragraph P_39 of length 16 across 1 children: 'Item H1>H3.L1.2'
#             │   │   ╰── List L_40: '<mistletoe.block_token.List with 1 child line_number=40 loose=False start=None at 0x106a02510>'
#             │   │       ╰── ListItem LI_40: "'* Item H1>H3.L1.subL.1\\n  * Item H1>H3.L1.subL.2\\n    * Item H1>H3.L1.subL.3\\n'"
#             │   │           ├── Paragraph P_40 of length 21 across 1 children: 'Item H1>H3.L1.subL.1'
#             │   │           ╰── List L_41: '<mistletoe.block_token.List with 1 child line_number=41 loose=False start=None at 0x106a026f0>'
#             │   │               ╰── ListItem LI_41: "'* Item H1>H3.L1.subL.2\\n  * Item H1>H3.L1.subL.3\\n'"
#             │   │                   ├── Paragraph P_41 of length 21 across 1 children: 'Item H1>H3.L1.subL.2'
#             │   │                   ╰── List L_42: '<mistletoe.block_token.List with 1 child line_number=42 loose=False start=None at 0x106a02840>'
#             │   │                       ╰── ListItem LI_42: "'* Item H1>H3.L1.subL.3\\n'"
#             │   │                           ╰── Paragraph P_42 of length 21 across 1 children: 'Item H1>H3.L1.subL.3'
#             │   ├── ListItem LI_43: "'* Item H1>H3.L1.1\\n'"
#             │   │   ╰── Paragraph P_43 of length 16 across 1 children: 'Item H1>H3.L1.1'
#             │   ╰── ListItem LI_44: "'* Item H1>H3.L1.2\\n'"
#             │       ╰── Paragraph P_44 of length 16 across 1 children: 'Item H1>H3.L1.2'
#             ├── BlankLine BL_45
#             ├── Paragraph P_46 of length 44 across 1 children: 'Paragraph before list with long list items.'
#             ├── List L_47: '<mistletoe.block_token.List with 6 children line_number=47 loose=False start=None at 0x106a029c0>'
#             │   ├── ListItem LI_47: "'* H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, '"
#             │   │   ╰── Paragraph P_47 of length 110 across 1 children: 'H1>H3.L2.1 -- Paragraph L2.item1,...(hidden)'
#             │   ├── ListItem LI_48: "'* H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, '"
#             │   │   ╰── Paragraph P_48 of length 142 across 1 children: 'H1>H3.L2.2 -- Paragraph L2.item2,...(hidden)'
#             │   ├── ListItem LI_49: "'* H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, '"
#             │   │   ╰── Paragraph P_49 of length 174 across 1 children: 'H1>H3.L2.3 -- Paragraph L2.item3,...(hidden)'
#             │   ├── ListItem LI_50: "'* H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, '"
#             │   │   ╰── Paragraph P_50 of length 110 across 1 children: 'H1>H3.L2.4 -- Paragraph L2.item1,...(hidden)'
#             │   ├── ListItem LI_51: "'* H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, '"
#             │   │   ╰── Paragraph P_51 of length 142 across 1 children: 'H1>H3.L2.5 -- Paragraph L2.item2,...(hidden)'
#             │   ╰── ListItem LI_52: "'* H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, '"
#             │       ╰── Paragraph P_52 of length 174 across 1 children: 'H1>H3.L2.6 -- Paragraph L2.item3,...(hidden)'
#             ├── BlankLine BL_53
#             ╰── Paragraph P_54 of length 17 across 1 children: 'Final paragraph.'

# %%
add_list_and_table_intros(tree)
# Out:
# 7

# %%
list_nodes = tree.find_all(match=lambda n: n.data_type == "List")
# Out:
# [Node<"List L_17: '<mistletoe.block_token.List with 3 children line_number=17 loose=False start=None at 0x106a00c80>'", data_id=L_17>,
#  Node<"List L_38: '<mistletoe.block_token.List with 4 children line_number=38 loose=False start=None at 0x106a02210>'", data_id=L_38>,
#  Node<"List L_40: '<mistletoe.block_token.List with 1 child line_number=40 loose=False start=None at 0x106a02510>'", data_id=L_40>,
#  Node<"List L_41: '<mistletoe.block_token.List with 1 child line_number=41 loose=False start=None at 0x106a026f0>'", data_id=L_41>,
#  Node<"List L_42: '<mistletoe.block_token.List with 1 child line_number=42 loose=False start=None at 0x106a02840>'", data_id=L_42>,
#  Node<"List L_47: '<mistletoe.block_token.List with 6 children line_number=47 loose=False start=None at 0x106a029c0>'", data_id=L_47>]

# %%
list_nodes[0].data["intro"]
# Out:
# 'List intro:\n'

# %%
[n.data["intro"] for n in list_nodes]
# Out:
# ['List intro:\n',
#  'Following list has *no* intro.\n',
#  'Item H1>H3.L1.2\n',
#  'Item H1>H3.L1.subL.1\n',
#  'Item H1>H3.L1.subL.2\n',
#  'Paragraph before list with long list items.\n']

# %%
table_node = tree.find_first(match=lambda n: n.data_type == "Table")
# Out:
# Node<"Table T_26: '| H3.2.T1: header 1     | H3.2.T1: header 2     | H3.2.T1: header 3     | H3.2.T1: header 4     |'", data_id=T_26>

# %%
table_node.data["intro"]
# Out:
# 'Table intro:\n'

# %% [markdown]
# #### Rendering the tree or subtrees
#
# (Reminder in preparation for chunking)

# %%
md = render_tree_as_md(tree)
print(md)
# Out:
# This is the first paragraph with no heading.
#
# # Heading 1
#
# First paragraph under Heading 1. Paragraph H1.p1, sentence 2. Paragraph H1.p1, sentence 3. Paragraph H1.p1, sentence 4. Last sentence of 'H1.p1'.
#
# Second paragraph under Heading 1. Paragraph H1.p2, sentence 2. Paragraph H1.p2, sentence 3. Paragraph H1.p2, sentence 4. Paragraph H1.p2, sentence 5. Paragraph H1.p2, sentence 6. Last sentence of 'H1.p2'.
#
# ## Heading 2
#
# Paragraph 1 under Heading 2 with [a link](http://to.nowhere.com). Paragraph H2.p1, sentence 2. Paragraph H2.p1, sentence 3. Paragraph H2.p1, sentence 4. Last sentence of 'H2.p1'.
#
# Paragraph 2 under Heading 2. Paragraph H2.p2, sentence 2. Paragraph H2.p2, sentence 3. Paragraph H2.p2, sentence 4. Paragraph H2.p2, sentence 5. Paragraph H2.p2, sentence 6. Last sentence of 'H2.p2'.
#
# List intro:
# * Item H2.3.L1.1
# * Item H2.3.L1.2
# * Item H2.3.L1.3
#
# ### Heading 3
#
# Only paragraph under **Heading 3**. Paragraph H3.p1, sentence 2. Paragraph H3.p1, sentence 3. Paragraph H3.p1, sentence 4. Last sentence.
#
# Table intro:
# | H3.2.T1: header 1     | H3.2.T1: header 2     | H3.2.T1: header 3     | H3.2.T1: header 4     |
# | --------------------- | --------------------- | --------------------- | --------------------- |
# | H3.2.T1: row 1, col 1 | H3.2.T1: row 1, col 2 | H3.2.T1: row 1, col 3 | H3.2.T1: row 1, col 4 |
# | H3.2.T1: row 2, col 1 | H3.2.T1: row 2, col 2 | H3.2.T1: row 2, col 3 | H3.2.T1: row 2, col 4 |
# | H3.2.T1: row 3, col 1 | H3.2.T1: row 3, col 2 | H3.2.T1: row 3, col 3 | H3.2.T1: row 3, col 4 |
#
# # Second H1 without a paragraph
#
# ### Skip to H3
#
# A paragraph under "Second H1>Heading 3". Paragraph H1>H3.p1, sentence 2. Paragraph H1>H3.p1, sentence 3. Following list has *no* intro.
#
# * Item H1>H3.L1.1
# * Item H1>H3.L1.2
#   * Item H1>H3.L1.subL.1
#     * Item H1>H3.L1.subL.2
#       * Item H1>H3.L1.subL.3
# * Item H1>H3.L1.1
# * Item H1>H3.L1.2
#
# Paragraph before list with long list items.
# * H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4.
# * H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5.
# * H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph L2.item3, sentence 6.
# * H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4.
# * H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5.
# * H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph L2.item3, sentence 6.
#
# Final paragraph.

# %%
print(render_subtree_as_md(tree.system_root.first_child()))
# Out:
# This is the first paragraph with no heading.
#
# # Heading 1
#
# First paragraph under Heading 1. Paragraph H1.p1, sentence 2. Paragraph H1.p1, sentence 3. Paragraph H1.p1, sentence 4. Last sentence of 'H1.p1'.
#
# Second paragraph under Heading 1. Paragraph H1.p2, sentence 2. Paragraph H1.p2, sentence 3. Paragraph H1.p2, sentence 4. Paragraph H1.p2, sentence 5. Paragraph H1.p2, sentence 6. Last sentence of 'H1.p2'.
#
# ## Heading 2
#
# Paragraph 1 under Heading 2 with [a link](http://to.nowhere.com). Paragraph H2.p1, sentence 2. Paragraph H2.p1, sentence 3. Paragraph H2.p1, sentence 4. Last sentence of 'H2.p1'.
#
# Paragraph 2 under Heading 2. Paragraph H2.p2, sentence 2. Paragraph H2.p2, sentence 3. Paragraph H2.p2, sentence 4. Paragraph H2.p2, sentence 5. Paragraph H2.p2, sentence 6. Last sentence of 'H2.p2'.
#
# List intro:
# * Item H2.3.L1.1
# * Item H2.3.L1.2
# * Item H2.3.L1.3
#
# ### Heading 3
#
# Only paragraph under **Heading 3**. Paragraph H3.p1, sentence 2. Paragraph H3.p1, sentence 3. Paragraph H3.p1, sentence 4. Last sentence.
#
# Table intro:
# | H3.2.T1: header 1     | H3.2.T1: header 2     | H3.2.T1: header 3     | H3.2.T1: header 4     |
# | --------------------- | --------------------- | --------------------- | --------------------- |
# | H3.2.T1: row 1, col 1 | H3.2.T1: row 1, col 2 | H3.2.T1: row 1, col 3 | H3.2.T1: row 1, col 4 |
# | H3.2.T1: row 2, col 1 | H3.2.T1: row 2, col 2 | H3.2.T1: row 2, col 3 | H3.2.T1: row 2, col 4 |
# | H3.2.T1: row 3, col 1 | H3.2.T1: row 3, col 2 | H3.2.T1: row 3, col 3 | H3.2.T1: row 3, col 4 |
#
# # Second H1 without a paragraph
#
# ### Skip to H3
#
# A paragraph under "Second H1>Heading 3". Paragraph H1>H3.p1, sentence 2. Paragraph H1>H3.p1, sentence 3. Following list has *no* intro.
#
# * Item H1>H3.L1.1
# * Item H1>H3.L1.2
#   * Item H1>H3.L1.subL.1
#     * Item H1>H3.L1.subL.2
#       * Item H1>H3.L1.subL.3
# * Item H1>H3.L1.1
# * Item H1>H3.L1.2
#
# Paragraph before list with long list items.
# * H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4.
# * H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5.
# * H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph L2.item3, sentence 6.
# * H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4.
# * H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5.
# * H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph L2.item3, sentence 6.
#
# Final paragraph.

# %% [markdown]
# ##### Comparing the input and output markdown

# %%
# TBD

# %% [markdown]
# ##### Checking token structure
#
# Expect no mismatches since we haven't done any significant changes to the tree.

# %%
mismatches = tokens_vs_tree_mismatches(tree)
pprint(mismatches, sort_dicts=False, width=120)
assert len(mismatches) == 0
# Out:
# defaultdict(<class 'list'>, {})

# %% [markdown]
# ### Chunking

# %%
from src.ingestion.markdown_chunking import *

# %% [markdown]
# Need some utilities for chunking.
#
# - Rendering to markdown a list of any nodes:

# %%
print(nodes_as_markdown([tree['L_38'], tree['BL_45'], tree['T_26']]))
# Out:
# * Item H1>H3.L1.1
# * Item H1>H3.L1.2
#   * Item H1>H3.L1.subL.1
#     * Item H1>H3.L1.subL.2
#       * Item H1>H3.L1.subL.3
# * Item H1>H3.L1.1
# * Item H1>H3.L1.2
#
# | H3.2.T1: header 1     | H3.2.T1: header 2     | H3.2.T1: header 3     | H3.2.T1: header 4     |
# | --------------------- | --------------------- | --------------------- | --------------------- |
# | H3.2.T1: row 1, col 1 | H3.2.T1: row 1, col 2 | H3.2.T1: row 1, col 3 | H3.2.T1: row 1, col 4 |
# | H3.2.T1: row 2, col 1 | H3.2.T1: row 2, col 2 | H3.2.T1: row 2, col 3 | H3.2.T1: row 2, col 4 |
# | H3.2.T1: row 3, col 1 | H3.2.T1: row 3, col 2 | H3.2.T1: row 3, col 3 | H3.2.T1: row 3, col 4 |

# %% [markdown]
# - Copying a subtree to its own tree.
#     - Think of a chunk as a subtree, except we can "summarize" subtrees to make them fit into a chunk.
#     - *Summarize* = create a chunk with the full content of the subtree, and add a short "summary" text to the node so that text can be used to chunk upper-level subtrees.
#     - Tech detail: `copy_subtree()` provides the "deep copy" capability so that it doesn't reference the original node.data and node.data.tokens (exception being the fozen tokens associated with `freeze_token_children`). This allows the new subtree to be modified without affecting the original tree.
#         - Used for splitting Lists/Tables into chunks with partial Lists/Tables

# %%
node = tree['L_47']
subtree = copy_subtree(node)
subtree.print()
# Out:
# Tree<'L_47 subtree'>
# ╰── List L_47: '<mistletoe.block_token.List with 6 children line_number=47 loose=False start=None at 0x106a15970>'
#     ├── ListItem LI_47: "'* H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, '"
#     │   ╰── Paragraph P_47 of length 110 across 1 children: 'H1>H3.L2.1 -- Paragraph L2.item1,...(hidden)'
#     ├── ListItem LI_48: "'* H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, '"
#     │   ╰── Paragraph P_48 of length 142 across 1 children: 'H1>H3.L2.2 -- Paragraph L2.item2,...(hidden)'
#     ├── ListItem LI_49: "'* H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, '"
#     │   ╰── Paragraph P_49 of length 174 across 1 children: 'H1>H3.L2.3 -- Paragraph L2.item3,...(hidden)'
#     ├── ListItem LI_50: "'* H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, '"
#     │   ╰── Paragraph P_50 of length 110 across 1 children: 'H1>H3.L2.4 -- Paragraph L2.item1,...(hidden)'
#     ├── ListItem LI_51: "'* H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, '"
#     │   ╰── Paragraph P_51 of length 142 across 1 children: 'H1>H3.L2.5 -- Paragraph L2.item2,...(hidden)'
#     ╰── ListItem LI_52: "'* H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, '"
#         ╰── Paragraph P_52 of length 174 across 1 children: 'H1>H3.L2.6 -- Paragraph L2.item3,...(hidden)'

# %% [markdown]
# - Get the headings (and potentially other context) is easy by leveraging the hierachical structure:

# %%
get_parent_headings_md(tree['LI_52'])
# Out:
# ['# Second H1 without a paragraph', '### Skip to H3']

# %% [markdown]
# #### Chunk tree

# %%
all_chunks=chunk_tree(tree)
pprint(list(all_chunks.values()), sort_dicts=False, width=140)
print("Total characters", sum(len(c.markdown) for c in all_chunks.values()))
len(all_chunks)
# Out:
# Splitting into chunks: Document D_1 with children: P_2, _S1_4, _S1_32
# Splitting into chunks: HeadingSection _S1_4 with children: H1_4, P_6, P_8, _S2_10
# Splitting into chunks: HeadingSection _S2_10 with children: H2_10, P_12, P_14, P_16, L_17, _S3_21
# Splitting into chunks: HeadingSection _S3_21 with children: H3_21, P_23, P_25, T_26
# ==> Chunked 0:T_26: 1 nodes, len 490: '| H3.2.T1: header 1 | H3.2.T1: header 2 | H3.2.T1: header 3 | H3.2.T1: header 4 |\n| --------------------- |...'
# ==> Chunked 1:H3_21: 7 nodes, len 268: '### Heading 3\n'
# ==> Chunked 2:H2_10: 10 nodes, len 493: '## Heading 2\n'
# ==> Chunked 3:H1_4: 7 nodes, len 399: '# Heading 1\n'
# Splitting into chunks: HeadingSection _S1_32 with children: H1_32, _S3_34
# Splitting into chunks: HeadingSection _S3_34 with children: H3_34, P_36, L_38, P_46, L_47, P_54
# Splitting into chunks: List L_47
# ==> Chunked 4:L_47[0]:LI_47: 1 nodes, len 303: '(Paragraph before list with long list items.)\n'
# ==> Chunked 5:L_47[1]:LI_49: 1 nodes, len 335: '(Paragraph before list with long list items.)\n'
# ==> Chunked 6:L_47[2]:LI_51: 1 nodes, len 367: '(Paragraph before list with long list items.)\n'
# ==> Chunked 7:H3_34: 10 nodes, len 480: '### Skip to H3\n'
# ==> Chunked 8:H1_32: 3 nodes, len 68: '# Second H1 without a paragraph\n'
# ==> Chunked 9:BL_1: 5 nodes, len 130: '\nThis is the first paragraph with no heading.'
# [Chunk(id='0:T_26',
#        headings=['# Heading 1', '## Heading 2', '### Heading 3'],
#        markdown='| H3.2.T1: header 1     | H3.2.T1: header 2     | H3.2.T1: header 3     | H3.2.T1: header 4     |\n'
#                 '| --------------------- | --------------------- | --------------------- | --------------------- |\n'
#                 '| H3.2.T1: row 1, col 1 | H3.2.T1: row 1, col 2 | H3.2.T1: row 1, col 3 | H3.2.T1: row 1, col 4 |\n'
#                 '| H3.2.T1: row 2, col 1 | H3.2.T1: row 2, col 2 | H3.2.T1: row 2, col 3 | H3.2.T1: row 2, col 4 |\n'
#                 '| H3.2.T1: row 3, col 1 | H3.2.T1: row 3, col 2 | H3.2.T1: row 3, col 3 | H3.2.T1: row 3, col 4 |\n'),
#  Chunk(id='1:H3_21',
#        headings=['# Heading 1', '## Heading 2'],
#        markdown='### Heading 3\n'
#                 '\n'
#                 'Only paragraph under **Heading 3**. Paragraph H3.p1, sentence 2. Paragraph H3.p1, sentence 3. Paragraph H3.p1, sentence '
#                 '4. Last sentence.\n'
#                 '\n'
#                 'Table intro:\n'
#                 '| H3.2.T1: header 1 | H3.2.T1: header 2 | H3.2.T1: header 3 | H3.2.T1: header 4 | (SUMMARY of T_26)\n'
#                 '\n'),
#  Chunk(id='2:H2_10',
#        headings=['# Heading 1'],
#        markdown='## Heading 2\n'
#                 '\n'
#                 'Paragraph 1 under Heading 2 with [a link](http://to.nowhere.com). Paragraph H2.p1, sentence 2. Paragraph H2.p1, sentence '
#                 "3. Paragraph H2.p1, sentence 4. Last sentence of 'H2.p1'.\n"
#                 '\n'
#                 'Paragraph 2 under Heading 2. Paragraph H2.p2, sentence 2. Paragraph H2.p2, sentence 3. Paragraph H2.p2, sentence 4. '
#                 "Paragraph H2.p2, sentence 5. Paragraph H2.p2, sentence 6. Last sentence of 'H2.p2'.\n"
#                 '\n'
#                 'List intro:\n'
#                 '* Item H2.3.L1.1\n'
#                 '* Item H2.3.L1.2\n'
#                 '* Item H2.3.L1.3\n'
#                 '\n'
#                 '### Heading 3 (SUMMARY of _S3_21)\n'),
#  Chunk(id='3:H1_4',
#        headings=[],
#        markdown='# Heading 1\n'
#                 '\n'
#                 'First paragraph under Heading 1. Paragraph H1.p1, sentence 2. Paragraph H1.p1, sentence 3. Paragraph H1.p1, sentence 4. '
#                 "Last sentence of 'H1.p1'.\n"
#                 '\n'
#                 'Second paragraph under Heading 1. Paragraph H1.p2, sentence 2. Paragraph H1.p2, sentence 3. Paragraph H1.p2, sentence 4. '
#                 "Paragraph H1.p2, sentence 5. Paragraph H1.p2, sentence 6. Last sentence of 'H1.p2'.\n"
#                 '\n'
#                 '## Heading 2 (SUMMARY of _S2_10)\n'),
#  Chunk(id='4:L_47[0]:LI_47',
#        headings=['# Second H1 without a paragraph', '### Skip to H3'],
#        markdown='(Paragraph before list with long list items.)\n'
#                 '\n'
#                 '* H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4.\n'
#                 '* H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph '
#                 'L2.item2, sentence 5.\n'),
#  Chunk(id='5:L_47[1]:LI_49',
#        headings=['# Second H1 without a paragraph', '### Skip to H3'],
#        markdown='(Paragraph before list with long list items.)\n'
#                 '\n'
#                 '* H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph '
#                 'L2.item3, sentence 5. Paragraph L2.item3, sentence 6.\n'
#                 '* H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph L2.item1, sentence 4.\n'),
#  Chunk(id='6:L_47[2]:LI_51',
#        headings=['# Second H1 without a paragraph', '### Skip to H3'],
#        markdown='(Paragraph before list with long list items.)\n'
#                 '\n'
#                 '* H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. Paragraph L2.item2, sentence 4. Paragraph '
#                 'L2.item2, sentence 5.\n'
#                 '* H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. Paragraph L2.item3, sentence 4. Paragraph '
#                 'L2.item3, sentence 5. Paragraph L2.item3, sentence 6.\n'),
#  Chunk(id='7:H3_34',
#        headings=['# Second H1 without a paragraph'],
#        markdown='### Skip to H3\n'
#                 '\n'
#                 'A paragraph under "Second H1>Heading 3". Paragraph H1>H3.p1, sentence 2. Paragraph H1>H3.p1, sentence 3. Following list '
#                 'has *no* intro.\n'
#                 '\n'
#                 '* Item H1>H3.L1.1\n'
#                 '* Item H1>H3.L1.2\n'
#                 '  * Item H1>H3.L1.subL.1\n'
#                 '    * Item H1>H3.L1.subL.2\n'
#                 '      * Item H1>H3.L1.subL.3\n'
#                 '* Item H1>H3.L1.1\n'
#                 '* Item H1>H3.L1.2\n'
#                 '\n'
#                 'Paragraph before list with long list items.\n'
#                 '* H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph... (SUMMARY of L_47)\n'
#                 '\n'
#                 'Final paragraph.\n'),
#  Chunk(id='8:H1_32', headings=[], markdown='# Second H1 without a paragraph\n\n### Skip to H3 (SUMMARY of _S3_34)\n'),
#  Chunk(id='9:BL_1',
#        headings=[],
#        markdown='\n'
#                 'This is the first paragraph with no heading.\n'
#                 '\n'
#                 '# Heading 1 (SUMMARY of _S1_4)\n'
#                 '# Second H1 without a paragraph (SUMMARY of _S1_32)\n')]
# Total characters 3333
# 10

# %%
for k,c in all_chunks.items():
    print(k, len(c.markdown))
# Out:
# 0:T_26 490
# 1:H3_21 268
# 2:H2_10 493
# 3:H1_4 399
# 4:L_47[0]:LI_47 303
# 5:L_47[1]:LI_49 335
# 6:L_47[2]:LI_51 367
# 7:H3_34 480
# 8:H1_32 68
# 9:BL_1 130

# %% [markdown]
# FIX:
# ```
# '10: _H3.34.split1.L47': ['# Second H1 without a paragraph\n'
#                         '### Skip to H3\n'
#                         '---\n'
#                         '* H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. Paragraph... '
#                         '(SUMMARY of L47)\n'],           <-- better summary of List/Table, maybe the intro?
# '11: _H1.32.split0.H1.32': ['# Second H1 without a paragraph\n### Skip to H3 (SUMMARY of _H3.34)\n'],  <--- same as below
# '12: D1.split0.BL1': ['This is the first paragraph with no heading.\n'      <--- better D1 chunk? Maybe just better summary of Headings?
#                     '# Heading 1 (SUMMARY of _H1.4)\n'
#                     '# Second H1 without a paragraph (SUMMARY of _H1.32)\n']})
# ```

# %% [markdown]
# ## EDD demo

# %%
h1section = "# Required Filings and Due Dates\n\nThis paragraph is under the first H1 heading."
list_md = (
    "### SUTA Dumping Hurts Everyone\n\n"
    "* List immediate after heading\n\n"
    "Employers, employees, and taxpayers make up the difference in higher taxes, lost jobs, lost profits, lower wages, and higher costs for goods and services.\n\n"
    "SUTA dumping:\n\n"
    "* Costs the UI trust fund millions of dollars each year. Sublist follows:\n\n"
    "    * Adversely affects tax rates for all employers.\n"
    "    * Creates inequity for compliant employers. [some link](https://edd.ca.gov/en/disability/pfl_claim_process/)\n"
    "* Eliminates the incentive for employers to avoid layoffs.\n"
    "    * Compromises the integrity of the UI system.\n\n"
    "### [SUTA Dumping Schemes](https://edd.ca.gov/en/payroll_taxes/suta_dumping/#collapse-2a82e068-3b29-4473-af7e-de9ea6961277)\n\n"
    "These schemes are meant to unlawfully lower an employer\u2019s UI tax rate. Employers should know about these schemes and their potential legal ramifications."
)
table_md = (
    "## Scheduled Events\n\n"
    "### Orientation\n\n"
    "**Career Center Orientation**\n"
    "| Location | Date/Time | Other Information |\n"
    "| --- | --- | --- |\n"
    "| Virtual | Friday | This workshop will ... |\n"
    "| Virtual | Fri | This workshop is for ... |\n"
    "| Virtual | F | Staff will conduct ... |\n"
)
first_paragraph = "This is the first paragraph with no heading."
last_paragraph ="This is the last paragraph. In markdown and html, we can't associate this under the first H1 heading."
markdown_document = "\n\n".join([first_paragraph, h1section, list_md, table_md, last_paragraph])
# Out:
# "This is the first paragraph with no heading.\n\n# Required Filings and Due Dates\n\nThis paragraph is under the first H1 heading.\n\n### SUTA Dumping Hurts Everyone\n\n* List immediate after heading\n\nEmployers, employees, and taxpayers make up the difference in higher taxes, lost jobs, lost profits, lower wages, and higher costs for goods and services.\n\nSUTA dumping:\n\n* Costs the UI trust fund millions of dollars each year. Sublist follows:\n\n    * Adversely affects tax rates for all employers.\n    * Creates inequity for compliant employers. [some link](https://edd.ca.gov/en/disability/pfl_claim_process/)\n* Eliminates the incentive for employers to avoid layoffs.\n    * Compromises the integrity of the UI system.\n\n### [SUTA Dumping Schemes](https://edd.ca.gov/en/payroll_taxes/suta_dumping/#collapse-2a82e068-3b29-4473-af7e-de9ea6961277)\n\nThese schemes are meant to unlawfully lower an employer’s UI tax rate. Employers should know about these schemes and their potential legal ramifications.\n\n## Scheduled Events\n\n### Orientation\n\n**Career Center Orientation**\n| Location | Date/Time | Other Information |\n| --- | --- | --- |\n| Virtual | Friday | This workshop will ... |\n| Virtual | Fri | This workshop is for ... |\n| Virtual | F | Staff will conduct ... |\n\n\nThis is the last paragraph. In markdown and html, we can't associate this under the first H1 heading."

# %%
print(markdown_document)
# Out:
# This is the first paragraph with no heading.
#
# # Required Filings and Due Dates
#
# This paragraph is under the first H1 heading.
#
# ### SUTA Dumping Hurts Everyone
#
# * List immediate after heading
#
# Employers, employees, and taxpayers make up the difference in higher taxes, lost jobs, lost profits, lower wages, and higher costs for goods and services.
#
# SUTA dumping:
#
# * Costs the UI trust fund millions of dollars each year. Sublist follows:
#
#     * Adversely affects tax rates for all employers.
#     * Creates inequity for compliant employers. [some link](https://edd.ca.gov/en/disability/pfl_claim_process/)
# * Eliminates the incentive for employers to avoid layoffs.
#     * Compromises the integrity of the UI system.
#
# ### [SUTA Dumping Schemes](https://edd.ca.gov/en/payroll_taxes/suta_dumping/#collapse-2a82e068-3b29-4473-af7e-de9ea6961277)
#
# These schemes are meant to unlawfully lower an employer’s UI tax rate. Employers should know about these schemes and their potential legal ramifications.
#
# ## Scheduled Events
#
# ### Orientation
#
# **Career Center Orientation**
# | Location | Date/Time | Other Information |
# | --- | --- | --- |
# | Virtual | Friday | This workshop will ... |
# | Virtual | Fri | This workshop is for ... |
# | Virtual | F | Staff will conduct ... |
#
#
# This is the last paragraph. In markdown and html, we can't associate this under the first H1 heading.

# %%
tree = create_markdown_tree(markdown_document, normalize_md=True)
tree.print()
# Out:
# Tree<'Markdown tree'>
# ╰── Document D_1: '<mistletoe.block_token.Document with 29 children line_number=1 at 0x106882420>'
#     ├── Paragraph P_1 of length 45 across 1 children
#     │   ╰── RawText s.65: "<mistletoe.span_token.RawText content='This is the first paragraph wi'...+14 at 0x106883080>"
#     ├── BlankLine BL_2
#     ├── Heading H1_3: '# Required Filings and Due Dates\n'
#     │   ╰── RawText s.66: "<mistletoe.span_token.RawText content='Required Filings and Due Dates' at 0x106a02480>"
#     ├── BlankLine BL_4
#     ├── Paragraph P_5 of length 46 across 1 children
#     │   ╰── RawText s.67: "<mistletoe.span_token.RawText content='This paragraph is under the fi'...+15 at 0x106a02f60>"
#     ├── BlankLine BL_6
#     ├── Heading H3_7: '### SUTA Dumping Hurts Everyone\n'
#     │   ╰── RawText s.68: "<mistletoe.span_token.RawText content='SUTA Dumping Hurts Everyone' at 0x106a00080>"
#     ├── BlankLine BL_8
#     ├── List L_9: '<mistletoe.block_token.List with 1 child line_number=9 loose=False start=None at 0x106a01520>'
#     │   ╰── ListItem LI_9: "'* List immediate after heading\\n'"
#     │       ╰── Paragraph P_9 of length 29 across 1 children
#     │           ╰── RawText s.69: "<mistletoe.span_token.RawText content='List immediate after heading' at 0x106a02780>"
#     ├── BlankLine BL_10
#     ├── Paragraph P_11 of length 155 across 1 children
#     │   ╰── RawText s.70: "<mistletoe.span_token.RawText content='Employers, employees, and taxp'...+124 at 0x106880200>"
#     ├── BlankLine BL_12
#     ├── Paragraph P_13 of length 14 across 1 children
#     │   ╰── RawText s.71: "<mistletoe.span_token.RawText content='SUTA dumping:' at 0x106a00740>"
#     ├── BlankLine BL_14
#     ├── List L_15: '<mistletoe.block_token.List with 2 children line_number=15 loose=False start=None at 0x106a03e60>'
#     │   ├── ListItem LI_15: "'* Costs the UI trust fund millions of dollars each year. Sublist follows:\\n\\n  * Adversely affects tax'"
#     │   │   ├── Paragraph P_15 of length 72 across 1 children
#     │   │   │   ╰── RawText s.72: "<mistletoe.span_token.RawText content='Costs the UI trust fund millio'...+41 at 0x106a01a90>"
#     │   │   ├── BlankLine BL_16
#     │   │   ╰── List L_17: '<mistletoe.block_token.List with 2 children line_number=17 loose=False start=None at 0x106a00bf0>'
#     │   │       ├── ListItem LI_17: "'* Adversely affects tax rates for all employers.\\n'"
#     │   │       │   ╰── Paragraph P_17 of length 47 across 1 children
#     │   │       │       ╰── RawText s.73: "<mistletoe.span_token.RawText content='Adversely affects tax rates fo'...+16 at 0x106a17230>"
#     │   │       ╰── ListItem LI_18: "'* Creates inequity for compliant employers. [some link](https://edd.ca.gov/en/disability/pfl_claim_p'"
#     │   │           ╰── Paragraph P_18 of length 107 across 2 children
#     │   │               ├── RawText s.74: "<mistletoe.span_token.RawText content='Creates inequity for compliant'...+12 at 0x106a3da00>"
#     │   │               ╰── Link s.75: '[some link](https://edd.ca.gov/en/disability/pfl_claim_process/)\n'
#     │   │                   ╰── RawText s.76: "<mistletoe.span_token.RawText content='some link' at 0x106a3d9d0>"
#     │   ╰── ListItem LI_19: "'* Eliminates the incentive for employers to avoid layoffs.\\n  * Compromises the integrity of the UI s'"
#     │       ├── Paragraph P_19 of length 57 across 1 children
#     │       │   ╰── RawText s.77: "<mistletoe.span_token.RawText content='Eliminates the incentive for e'...+26 at 0x106a3e3c0>"
#     │       ╰── List L_20: '<mistletoe.block_token.List with 1 child line_number=20 loose=False start=None at 0x106a3ee70>'
#     │           ╰── ListItem LI_20: "'* Compromises the integrity of the UI system.\\n'"
#     │               ╰── Paragraph P_20 of length 44 across 1 children
#     │                   ╰── RawText s.78: "<mistletoe.span_token.RawText content='Compromises the integrity of t'...+13 at 0x106a16ab0>"
#     ├── BlankLine BL_21
#     ├── Heading H3_22: '### [SUTA Dumping Schemes](https://edd.ca.gov/en/payroll_taxes/suta_dumping/#collapse-2a82e068-3b29-4473-af7e-de9ea6961277)\n'
#     │   ╰── Link s.79: '[SUTA Dumping Schemes](https://edd.ca.gov/en/payroll_taxes/suta_dumping/#collapse-2a82e068-3b29-4473-af7e-de9ea6961277)\n'
#     │       ╰── RawText s.80: "<mistletoe.span_token.RawText content='SUTA Dumping Schemes' at 0x106a3d700>"
#     ├── BlankLine BL_23
#     ├── Paragraph P_24 of length 154 across 1 children
#     │   ╰── RawText s.81: "<mistletoe.span_token.RawText content='These schemes are meant to unl'...+123 at 0x10687f380>"
#     ├── BlankLine BL_25
#     ├── Heading H2_26: '## Scheduled Events\n'
#     │   ╰── RawText s.82: "<mistletoe.span_token.RawText content='Scheduled Events' at 0x106a3d220>"
#     ├── BlankLine BL_27
#     ├── Heading H3_28: '### Orientation\n'
#     │   ╰── RawText s.83: "<mistletoe.span_token.RawText content='Orientation' at 0x106a15d30>"
#     ├── BlankLine BL_29
#     ├── Paragraph P_30 of length 30 across 1 children
#     │   ╰── Strong s.84: '<mistletoe.span_token.Strong with 1 child at 0x106a3fb00>'
#     │       ╰── RawText s.85: "<mistletoe.span_token.RawText content='Career Center Orientation' at 0x106a3f650>"
#     ├── Table T_31: '| Location | Date/Time | Other Information        |'
#     │   ├── TableRow TR_33: '| Virtual  | Friday    | This workshop will ...   |'
#     │   │   ├── TableCell tc86_33
#     │   │   │   ╰── RawText s.87: "<mistletoe.span_token.RawText content='Virtual' at 0x106a155b0>"
#     │   │   ├── TableCell tc88_33
#     │   │   │   ╰── RawText s.89: "<mistletoe.span_token.RawText content='Friday' at 0x106a17140>"
#     │   │   ╰── TableCell tc90_33
#     │   │       ╰── RawText s.91: "<mistletoe.span_token.RawText content='This workshop will ...' at 0x106a15520>"
#     │   ├── TableRow TR_34: '| Virtual  | Fri       | This workshop is for ... |'
#     │   │   ├── TableCell tc92_34
#     │   │   │   ╰── RawText s.93: "<mistletoe.span_token.RawText content='Virtual' at 0x106a3eba0>"
#     │   │   ├── TableCell tc94_34
#     │   │   │   ╰── RawText s.95: "<mistletoe.span_token.RawText content='Fri' at 0x106a16c90>"
#     │   │   ╰── TableCell tc96_34
#     │   │       ╰── RawText s.97: "<mistletoe.span_token.RawText content='This workshop is for ...' at 0x106a3e1e0>"
#     │   ╰── TableRow TR_35: '| Virtual  | F         | Staff will conduct ...   |'
#     │       ├── TableCell tc98_35
#     │       │   ╰── RawText s.99: "<mistletoe.span_token.RawText content='Virtual' at 0x106a149e0>"
#     │       ├── TableCell tc100_35
#     │       │   ╰── RawText s.101: "<mistletoe.span_token.RawText content='F' at 0x106a17ce0>"
#     │       ╰── TableCell tc102_35
#     │           ╰── RawText s.103: "<mistletoe.span_token.RawText content='Staff will conduct ...' at 0x106a14fb0>"
#     ├── BlankLine BL_36
#     ├── BlankLine BL_37
#     ╰── Paragraph P_38 of length 102 across 1 children
#         ╰── RawText s.104: "<mistletoe.span_token.RawText content='This is the last paragraph. In'...+71 at 0x106a16360>"

# %% [markdown]
# ### Tree Prep

# %%
hide_span_tokens(tree)
# Out:
# 21

# %%
create_heading_sections(tree)
# Out:
# 5

# %%
tokens_vs_tree_mismatches(tree)
# Out:
# defaultdict(list, {})

# %%
print(nest_heading_sections(tree))
tree.print()
tokens_vs_tree_mismatches(tree)
print(len(tree))
# Out:
# 4
# Tree<'Markdown tree'>
# ╰── Document D_1: '<mistletoe.block_token.Document with 29 children line_number=1 at 0x106882420>'
#     ├── Paragraph P_1 of length 45 across 1 children: 'This is the first paragraph with no heading.'
#     ├── BlankLine BL_2
#     ╰── HeadingSection _S1_3 with 7 children
#         ├── Heading H1_3: '# Required Filings and Due Dates'
#         ├── BlankLine BL_4
#         ├── Paragraph P_5 of length 46 across 1 children: 'This paragraph is under the first H1 heading.'
#         ├── BlankLine BL_6
#         ├── HeadingSection _S3_7 with 10 children
#         │   ├── Heading H3_7: '### SUTA Dumping Hurts Everyone'
#         │   ├── BlankLine BL_8
#         │   ├── List L_9: '<mistletoe.block_token.List with 1 child line_number=9 loose=False start=None at 0x106a01520>'
#         │   │   ╰── ListItem LI_9: "'* List immediate after heading\\n'"
#         │   │       ╰── Paragraph P_9 of length 29 across 1 children: 'List immediate after heading'
#         │   ├── BlankLine BL_10
#         │   ├── Paragraph P_11 of length 155 across 1 children: 'Employers, employees, and taxpayers...(hidden)'
#         │   ├── BlankLine BL_12
#         │   ├── Paragraph P_13 of length 14 across 1 children: 'SUTA dumping:'
#         │   ├── BlankLine BL_14
#         │   ├── List L_15: '<mistletoe.block_token.List with 2 children line_number=15 loose=False start=None at 0x106a03e60>'
#         │   │   ├── ListItem LI_15: "'* Costs the UI trust fund millions of dollars each year. Sublist follows:\\n\\n  * Adversely affects tax'"
#         │   │   │   ├── Paragraph P_15 of length 72 across 1 children: 'Costs the UI trust fund millions of...(hidden)'
#         │   │   │   ├── BlankLine BL_16
#         │   │   │   ╰── List L_17: '<mistletoe.block_token.List with 2 children line_number=17 loose=False start=None at 0x106a00bf0>'
#         │   │   │       ├── ListItem LI_17: "'* Adversely affects tax rates for all employers.\\n'"
#         │   │   │       │   ╰── Paragraph P_17 of length 47 across 1 children: 'Adversely affects tax rates for all employers.'
#         │   │   │       ╰── ListItem LI_18: "'* Creates inequity for compliant employers. [some link](https://edd.ca.gov/en/disability/pfl_claim_p'"
#         │   │   │           ╰── Paragraph P_18 of length 107 across 2 children: 'Creates inequity for compliant...(hidden)'
#         │   │   ╰── ListItem LI_19: "'* Eliminates the incentive for employers to avoid layoffs.\\n  * Compromises the integrity of the UI s'"
#         │   │       ├── Paragraph P_19 of length 57 across 1 children: 'Eliminates the incentive for employers...(hidden)'
#         │   │       ╰── List L_20: '<mistletoe.block_token.List with 1 child line_number=20 loose=False start=None at 0x106a3ee70>'
#         │   │           ╰── ListItem LI_20: "'* Compromises the integrity of the UI system.\\n'"
#         │   │               ╰── Paragraph P_20 of length 44 across 1 children: 'Compromises the integrity of the UI system.'
#         │   ╰── BlankLine BL_21
#         ├── HeadingSection _S3_22 with 4 children
#         │   ├── Heading H3_22: '### [SUTA Dumping...(hidden)'
#         │   ├── BlankLine BL_23
#         │   ├── Paragraph P_24 of length 154 across 1 children: 'These schemes are meant to unlawfully...(hidden)'
#         │   ╰── BlankLine BL_25
#         ╰── HeadingSection _S2_26 with 3 children
#             ├── Heading H2_26: '## Scheduled Events'
#             ├── BlankLine BL_27
#             ╰── HeadingSection _S3_28 with 7 children
#                 ├── Heading H3_28: '### Orientation'
#                 ├── BlankLine BL_29
#                 ├── Paragraph P_30 of length 30 across 1 children: '**Career Center Orientation**'
#                 ├── Table T_31: '| Location | Date/Time | Other Information        |'
#                 │   ├── TableRow TR_33: '| Virtual | Friday | This workshop will ... |'
#                 │   ├── TableRow TR_34: '| Virtual | Fri | This workshop is for ... |'
#                 │   ╰── TableRow TR_35: '| Virtual | F | Staff will conduct ... |'
#                 ├── BlankLine BL_36
#                 ├── BlankLine BL_37
#                 ╰── Paragraph P_38 of length 102 across 1 children: 'This is the last paragraph. In markdown...(hidden)'
# 53

# %%
add_list_and_table_intros(tree)
# Out:
# 5

# %% [markdown]
# ### Tree examination

# %%
tokens_vs_tree_mismatches(tree)
# Out:
# defaultdict(list, {})

# %%
md = render_tree_as_md(tree)
print(md)
# Out:
# This is the first paragraph with no heading.
#
# # Required Filings and Due Dates
#
# This paragraph is under the first H1 heading.
#
# ### SUTA Dumping Hurts Everyone
#
# * List immediate after heading
#
# Employers, employees, and taxpayers make up the difference in higher taxes, lost jobs, lost profits, lower wages, and higher costs for goods and services.
#
# SUTA dumping:
#
# * Costs the UI trust fund millions of dollars each year. Sublist follows:
#
#   * Adversely affects tax rates for all employers.
#   * Creates inequity for compliant employers. [some link](https://edd.ca.gov/en/disability/pfl_claim_process/)
# * Eliminates the incentive for employers to avoid layoffs.
#   * Compromises the integrity of the UI system.
#
# ### [SUTA Dumping Schemes](https://edd.ca.gov/en/payroll_taxes/suta_dumping/#collapse-2a82e068-3b29-4473-af7e-de9ea6961277)
#
# These schemes are meant to unlawfully lower an employer’s UI tax rate. Employers should know about these schemes and their potential legal ramifications.
#
# ## Scheduled Events
#
# ### Orientation
#
# **Career Center Orientation**
# | Location | Date/Time | Other Information        |
# | -------- | --------- | ------------------------ |
# | Virtual  | Friday    | This workshop will ...   |
# | Virtual  | Fri       | This workshop is for ... |
# | Virtual  | F         | Staff will conduct ...   |
#
#
# This is the last paragraph. In markdown and html, we can't associate this under the first H1 heading.

# %%
describe_tree(tree)
# Out:
# {'counts': defaultdict(int,
#              {'Document': 1,
#               'Paragraph': 13,
#               'BlankLine': 15,
#               'HeadingSection': 5,
#               'Heading': 5,
#               'List': 4,
#               'ListItem': 6,
#               'Table': 1,
#               'TableRow': 3}),
#  'children': defaultdict(set,
#              {'Document': {'BlankLine', 'HeadingSection', 'Paragraph'},
#               'HeadingSection': {'BlankLine',
#                'Heading',
#                'HeadingSection',
#                'List',
#                'Paragraph',
#                'Table'},
#               'List': {'ListItem'},
#               'ListItem': {'BlankLine', 'List', 'Paragraph'},
#               'Table': {'TableRow'}}),
#  'parents': defaultdict(set,
#              {'Paragraph': {'Document', 'HeadingSection', 'ListItem'},
#               'BlankLine': {'Document', 'HeadingSection', 'ListItem'},
#               'HeadingSection': {'Document', 'HeadingSection'},
#               'Heading': {'HeadingSection'},
#               'List': {'HeadingSection', 'ListItem'},
#               'ListItem': {'List'},
#               'Table': {'HeadingSection'},
#               'TableRow': {'Table'}}),
#  'tokens': defaultdict(set,
#              {'Document': {'_children',
#                'data_id',
#                'footnotes',
#                'line_number',
#                'type'},
#               'Paragraph': {'_children',
#                '_parent',
#                'data_id',
#                'line_number',
#                'type'},
#               'BlankLine': {'_children',
#                '_parent',
#                'data_id',
#                'line_number',
#                'type'},
#               'Heading': {'_children',
#                '_parent',
#                'closing_sequence',
#                'data_id',
#                'level',
#                'line_number',
#                'type'},
#               'List': {'_children',
#                '_parent',
#                'data_id',
#                'line_number',
#                'loose',
#                'start',
#                'type'},
#               'ListItem': {'_children',
#                '_parent',
#                'data_id',
#                'indentation',
#                'leader',
#                'line_number',
#                'loose',
#                'prepend',
#                'type'},
#               'Table': {'_children',
#                '_parent',
#                'column_align',
#                'data_id',
#                'header',
#                'line_number',
#                'type'},
#               'TableRow': {'_children',
#                '_parent',
#                'col_widths',
#                'column_align',
#                'data_id',
#                'line_number',
#                'row_align',
#                'sep_line',
#                'type'}})}

# %% [markdown]
# ### Chunking

# %%
# heading_sections = [n for n in tree.iterator(method=IterMethod.POST_ORDER) if n.data.type == "HeadingSection"]
hierarchically_chunk_nodes(tree.children[0])
pprint(all_chunks, sort_dicts=False, width=120)
print(len(all_chunks))
sum(len(c.markdown) for c in all_chunks.values())
# Out:
# Splitting into chunks: Document D_1 with children: P_1, _S1_3
# Splitting into chunks: HeadingSection _S1_3 with children: H1_3, P_5, _S3_7, _S3_22, _S2_26
# ==> Chunked 10:_S3_7: 1 nodes, len 587: '### SUTA Dumping Hurts Everyone\n'
# ==> Chunked 11:_S2_26: 1 nodes, len 440: '## Scheduled Events\n'
# ==> Chunked 12:H1_3: 7 nodes, len 455: '# Required Filings and Due Dates\n'
# ==> Chunked 13:P_1: 3 nodes, len 98: 'This is the first paragraph with no heading.\n'
# {'0:T_26': Chunk(id='0:T_26',
#                  headings=['# Heading 1', '## Heading 2', '### Heading 3'],
#                  markdown='| H3.2.T1: header 1     | H3.2.T1: header 2     | H3.2.T1: header 3     | H3.2.T1: header '
#                           '4     |\n'
#                           '| --------------------- | --------------------- | --------------------- | '
#                           '--------------------- |\n'
#                           '| H3.2.T1: row 1, col 1 | H3.2.T1: row 1, col 2 | H3.2.T1: row 1, col 3 | H3.2.T1: row 1, '
#                           'col 4 |\n'
#                           '| H3.2.T1: row 2, col 1 | H3.2.T1: row 2, col 2 | H3.2.T1: row 2, col 3 | H3.2.T1: row 2, '
#                           'col 4 |\n'
#                           '| H3.2.T1: row 3, col 1 | H3.2.T1: row 3, col 2 | H3.2.T1: row 3, col 3 | H3.2.T1: row 3, '
#                           'col 4 |\n'),
#  '1:H3_21': Chunk(id='1:H3_21',
#                   headings=['# Heading 1', '## Heading 2'],
#                   markdown='### Heading 3\n'
#                            '\n'
#                            'Only paragraph under **Heading 3**. Paragraph H3.p1, sentence 2. Paragraph H3.p1, sentence '
#                            '3. Paragraph H3.p1, sentence 4. Last sentence.\n'
#                            '\n'
#                            'Table intro:\n'
#                            '| H3.2.T1: header 1 | H3.2.T1: header 2 | H3.2.T1: header 3 | H3.2.T1: header 4 | (SUMMARY '
#                            'of T_26)\n'
#                            '\n'),
#  '2:H2_10': Chunk(id='2:H2_10',
#                   headings=['# Heading 1'],
#                   markdown='## Heading 2\n'
#                            '\n'
#                            'Paragraph 1 under Heading 2 with [a link](http://to.nowhere.com). Paragraph H2.p1, '
#                            'sentence 2. Paragraph H2.p1, sentence 3. Paragraph H2.p1, sentence 4. Last sentence of '
#                            "'H2.p1'.\n"
#                            '\n'
#                            'Paragraph 2 under Heading 2. Paragraph H2.p2, sentence 2. Paragraph H2.p2, sentence 3. '
#                            'Paragraph H2.p2, sentence 4. Paragraph H2.p2, sentence 5. Paragraph H2.p2, sentence 6. '
#                            "Last sentence of 'H2.p2'.\n"
#                            '\n'
#                            'List intro:\n'
#                            '* Item H2.3.L1.1\n'
#                            '* Item H2.3.L1.2\n'
#                            '* Item H2.3.L1.3\n'
#                            '\n'
#                            '### Heading 3 (SUMMARY of _S3_21)\n'),
#  '3:H1_4': Chunk(id='3:H1_4',
#                  headings=[],
#                  markdown='# Heading 1\n'
#                           '\n'
#                           'First paragraph under Heading 1. Paragraph H1.p1, sentence 2. Paragraph H1.p1, sentence 3. '
#                           "Paragraph H1.p1, sentence 4. Last sentence of 'H1.p1'.\n"
#                           '\n'
#                           'Second paragraph under Heading 1. Paragraph H1.p2, sentence 2. Paragraph H1.p2, sentence 3. '
#                           'Paragraph H1.p2, sentence 4. Paragraph H1.p2, sentence 5. Paragraph H1.p2, sentence 6. Last '
#                           "sentence of 'H1.p2'.\n"
#                           '\n'
#                           '## Heading 2 (SUMMARY of _S2_10)\n'),
#  '4:L_47[0]:LI_47': Chunk(id='4:L_47[0]:LI_47',
#                           headings=['# Second H1 without a paragraph', '### Skip to H3'],
#                           markdown='(Paragraph before list with long list items.)\n'
#                                    '\n'
#                                    '* H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. '
#                                    'Paragraph L2.item1, sentence 4.\n'
#                                    '* H1>H3.L2.2 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. '
#                                    'Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5.\n'),
#  '5:L_47[1]:LI_49': Chunk(id='5:L_47[1]:LI_49',
#                           headings=['# Second H1 without a paragraph', '### Skip to H3'],
#                           markdown='(Paragraph before list with long list items.)\n'
#                                    '\n'
#                                    '* H1>H3.L2.3 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. '
#                                    'Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph '
#                                    'L2.item3, sentence 6.\n'
#                                    '* H1>H3.L2.4 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. '
#                                    'Paragraph L2.item1, sentence 4.\n'),
#  '6:L_47[2]:LI_51': Chunk(id='6:L_47[2]:LI_51',
#                           headings=['# Second H1 without a paragraph', '### Skip to H3'],
#                           markdown='(Paragraph before list with long list items.)\n'
#                                    '\n'
#                                    '* H1>H3.L2.5 -- Paragraph L2.item2, sentence 2. Paragraph L2.item2, sentence 3. '
#                                    'Paragraph L2.item2, sentence 4. Paragraph L2.item2, sentence 5.\n'
#                                    '* H1>H3.L2.6 -- Paragraph L2.item3, sentence 2. Paragraph L2.item3, sentence 3. '
#                                    'Paragraph L2.item3, sentence 4. Paragraph L2.item3, sentence 5. Paragraph '
#                                    'L2.item3, sentence 6.\n'),
#  '7:H3_34': Chunk(id='7:H3_34',
#                   headings=['# Second H1 without a paragraph'],
#                   markdown='### Skip to H3\n'
#                            '\n'
#                            'A paragraph under "Second H1>Heading 3". Paragraph H1>H3.p1, sentence 2. Paragraph '
#                            'H1>H3.p1, sentence 3. Following list has *no* intro.\n'
#                            '\n'
#                            '* Item H1>H3.L1.1\n'
#                            '* Item H1>H3.L1.2\n'
#                            '  * Item H1>H3.L1.subL.1\n'
#                            '    * Item H1>H3.L1.subL.2\n'
#                            '      * Item H1>H3.L1.subL.3\n'
#                            '* Item H1>H3.L1.1\n'
#                            '* Item H1>H3.L1.2\n'
#                            '\n'
#                            'Paragraph before list with long list items.\n'
#                            '* H1>H3.L2.1 -- Paragraph L2.item1, sentence 2. Paragraph L2.item1, sentence 3. '
#                            'Paragraph... (SUMMARY of L_47)\n'
#                            '\n'
#                            'Final paragraph.\n'),
#  '8:H1_32': Chunk(id='8:H1_32',
#                   headings=[],
#                   markdown='# Second H1 without a paragraph\n\n### Skip to H3 (SUMMARY of _S3_34)\n'),
#  '9:BL_1': Chunk(id='9:BL_1',
#                  headings=[],
#                  markdown='\n'
#                           'This is the first paragraph with no heading.\n'
#                           '\n'
#                           '# Heading 1 (SUMMARY of _S1_4)\n'
#                           '# Second H1 without a paragraph (SUMMARY of _S1_32)\n'),
#  '10:_S3_7': Chunk(id='10:_S3_7',
#                    headings=['# Required Filings and Due Dates'],
#                    markdown='### SUTA Dumping Hurts Everyone\n'
#                             '\n'
#                             '\n'
#                             '\n'
#                             '* List immediate after heading\n'
#                             '\n'
#                             'Employers, employees, and taxpayers make up the difference in higher taxes, lost jobs, '
#                             'lost profits, lower wages, and higher costs for goods and services.\n'
#                             '\n'
#                             '\n'
#                             '\n'
#                             'SUTA dumping:\n'
#                             '\n'
#                             '\n'
#                             '\n'
#                             '* Costs the UI trust fund millions of dollars each year. Sublist follows:\n'
#                             '\n'
#                             '  * Adversely affects tax rates for all employers.\n'
#                             '  * Creates inequity for compliant employers. [some '
#                             'link](https://edd.ca.gov/en/disability/pfl_claim_process/)\n'
#                             '* Eliminates the incentive for employers to avoid layoffs.\n'
#                             '  * Compromises the integrity of the UI system.\n'
#                             '\n'),
#  '11:_S2_26': Chunk(id='11:_S2_26',
#                     headings=['# Required Filings and Due Dates'],
#                     markdown='## Scheduled Events\n'
#                              '\n'
#                              '\n'
#                              '\n'
#                              '### Orientation\n'
#                              '\n'
#                              '\n'
#                              '\n'
#                              '**Career Center Orientation**\n'
#                              '\n'
#                              '| Location | Date/Time | Other Information        |\n'
#                              '| -------- | --------- | ------------------------ |\n'
#                              '| Virtual  | Friday    | This workshop will ...   |\n'
#                              '| Virtual  | Fri       | This workshop is for ... |\n'
#                              '| Virtual  | F         | Staff will conduct ...   |\n'
#                              '\n'
#                              '\n'
#                              '\n'
#                              '\n'
#                              '\n'
#                              "This is the last paragraph. In markdown and html, we can't associate this under the "
#                              'first H1 heading.\n'),
#  '12:H1_3': Chunk(id='12:H1_3',
#                   headings=[],
#                   markdown='# Required Filings and Due Dates\n'
#                            '\n'
#                            'This paragraph is under the first H1 heading.\n'
#                            '\n'
#                            '### SUTA Dumping Hurts Everyone (SUMMARY of _S3_7)\n'
#                            '### [SUTA Dumping '
#                            'Schemes](https://edd.ca.gov/en/payroll_taxes/suta_dumping/#collapse-2a82e068-3b29-4473-af7e-de9ea6961277)\n'
#                            '\n'
#                            '\n'
#                            '\n'
#                            'These schemes are meant to unlawfully lower an employer’s UI tax rate. Employers should '
#                            'know about these schemes and their potential legal ramifications.\n'
#                            '\n'
#                            '\n'
#                            '## Scheduled Events (SUMMARY of _S2_26)\n'),
#  '13:P_1': Chunk(id='13:P_1',
#                  headings=[],
#                  markdown='This is the first paragraph with no heading.\n'
#                           '\n'
#                           '# Required Filings and Due Dates (SUMMARY of _S1_3)\n')}
# 14
# 4913

# %% [markdown]
# ```
# ok?:
#              '5:P13': ['# Required Filings and Due Dates\n### SUTA Dumping Hurts Everyone\n--\nSUTA dumping:\n'],
# ```

# %%
len(md)
# Out:
# 1420

# %%
print(md)
# Out:
# This is the first paragraph with no heading.
#
# # Required Filings and Due Dates
#
# This paragraph is under the first H1 heading.
#
# ### SUTA Dumping Hurts Everyone
#
# * List immediate after heading
#
# Employers, employees, and taxpayers make up the difference in higher taxes, lost jobs, lost profits, lower wages, and higher costs for goods and services.
#
# SUTA dumping:
#
# * Costs the UI trust fund millions of dollars each year. Sublist follows:
#
#   * Adversely affects tax rates for all employers.
#   * Creates inequity for compliant employers. [some link](https://edd.ca.gov/en/disability/pfl_claim_process/)
# * Eliminates the incentive for employers to avoid layoffs.
#   * Compromises the integrity of the UI system.
#
# ### [SUTA Dumping Schemes](https://edd.ca.gov/en/payroll_taxes/suta_dumping/#collapse-2a82e068-3b29-4473-af7e-de9ea6961277)
#
# These schemes are meant to unlawfully lower an employer’s UI tax rate. Employers should know about these schemes and their potential legal ramifications.
#
# ## Scheduled Events
#
# ### Orientation
#
# **Career Center Orientation**
# | Location | Date/Time | Other Information        |
# | -------- | --------- | ------------------------ |
# | Virtual  | Friday    | This workshop will ...   |
# | Virtual  | Fri       | This workshop is for ... |
# | Virtual  | F         | Staff will conduct ...   |
#
#
# This is the last paragraph. In markdown and html, we can't associate this under the first H1 heading.
